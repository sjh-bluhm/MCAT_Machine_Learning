# %%
#import necessary modules
#Python >= 3.5
import sys
assert sys.version_info >= (3, 5)

#Scikit-Learn >= 0.20
import sklearn as sk
assert sk.__version__ >= "0.20"
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

#numpy for calculations
import numpy as np
import os

#matplotlib for figures
import matplotlib as mpl
import matplotlib.pyplot as plt
#a magic function that allows inline plotting so figures are rendered in this notebook
# %matplotlib inline

#pandas for ...
import pandas as pd
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Setup and Feature Statistics

# %%
# load data from the cv file using pandas
scores = pd.read_csv("Numeric Only Complete MCAT Data.csv", header = 1)

# rename some columns for consistency
scores.rename(columns = {'Days Before Exam':'Days Before Exam.1', 'Days Before Exam.1':'Days Before Exam.2', 'Days Before Exam.2':'Days Before Exam.3', 'Days Before Exam.3':'Days Before Exam.4'}, inplace = True)

# preview first five lines
scores.head()
# Out:
#    Real Score  C/P Score  CARS Score  B/B Score  P/S Score  \
# 0       513.0      128.0       128.0      129.0      128.0
# 1       495.0      122.0       127.0      122.0      124.0
# 2       522.0      130.0       129.0      131.0      132.0
# 3       515.0      128.0       129.0      128.0      130.0
# 4       522.0      131.0       131.0      130.0      130.0
#
#    Days Before Exam.1  Total Score  C/P Score.1  CARS Score.1  B/B Score.1  \
# 0                 NaN          NaN          NaN           NaN          NaN
# 1                 NaN          NaN          NaN           NaN          NaN
# 2                 5.0        519.0        129.0         129.0        129.0
# 3                 7.0        515.0        129.0         128.0        128.0
# 4                 8.0        519.0        131.0         129.0        128.0
#
#    ...  C/P Score.3  CARS Score.3  B/B Score.3  P/S Score.3  \
# 0  ...        128.0         128.0        128.0        126.0
# 1  ...          NaN           NaN          NaN          NaN
# 2  ...          NaN           NaN          NaN          NaN
# 3  ...        127.0         127.0        129.0        127.0
# 4  ...        130.0         129.0        130.0        131.0
#
#    Days Before Exam.4  Total Score.3  C/P Score.4  CARS Score.4  B/B Score.4  \
# 0                16.0          506.0        127.0         127.0        125.0
# 1                 NaN            NaN          NaN           NaN          NaN
# 2               512.0            NaN          NaN           NaN          NaN
# 3                28.0          506.0        127.0         125.0        127.0
# 4                15.0          519.0        129.0         130.0        129.0
#
#    P/S Score.4
# 0        127.0
# 1          NaN
# 2          NaN
# 3        127.0
# 4        131.0
#
# [5 rows x 29 columns]

# %%
# drop irrelevant columns
scores.drop(columns=['C/P Score', 'CARS Score', 'B/B Score', 'P/S Score', 'Total Score', 'Total Score.1', 'Total Score.2', 'Total Score.3'], inplace = True)

# sanity check: take a look at the data
print('Scores data shape:', scores.shape)

# look at distribution of scores
scores['Real Score'].value_counts()

# gives count, mean, standard deviation, min, max, and percentiles (including median)
scores.describe(percentiles = [0.25, 0.5, 0.75], include = 'all')
# Out:
# Scores data shape: (4996, 21)
#         Real Score  Days Before Exam.1  C/P Score.1  CARS Score.1  \
# count  4948.000000         1733.000000  1502.000000   1498.000000
# mean    515.914511            8.417773   129.312250    128.403872
# std      23.805011           16.390119     1.996091      2.083215
# min     417.000000            0.000000   120.000000    120.000000
# 25%     512.000000            4.000000   128.000000    127.000000
# 50%     517.000000            6.000000   130.000000    129.000000
# 75%     520.000000            7.000000   131.000000    130.000000
# max    2115.000000          365.000000   132.000000    132.000000
#
#        B/B Score.1  P/S Score.1  Days Before Exam.2  C/P Score.2  \
# count  1496.000000  1496.000000         2567.000000  2330.000000
# mean    129.037433   129.328877           21.421504   129.054506
# std       1.835347     1.885376          365.928234     1.919827
# min     122.000000   122.000000        -8764.000000   121.000000
# 25%     128.000000   128.000000            6.000000   128.000000
# 50%     129.000000   130.000000            9.000000   129.000000
# 75%     130.000000   131.000000           14.000000   130.000000
# max     132.000000   132.000000        10227.000000   132.000000
#
#        CARS Score.2  B/B Score.2  ...  Days Before Exam.3  C/P Score.3  \
# count   2329.000000  2327.000000  ...         3302.000000  3044.000000
# mean     128.280807   129.329179  ...           15.140218   128.729632
# std        2.156899     1.804962  ...          318.873762     1.988670
# min      122.000000   120.000000  ...        -8760.000000   118.000000
# 25%      127.000000   128.000000  ...            7.000000   127.000000
# 50%      128.000000   130.000000  ...           14.000000   129.000000
# 75%      130.000000   131.000000  ...           21.000000   130.000000
# max      132.000000   132.000000  ...         6712.000000   132.000000
#
#        CARS Score.3  B/B Score.3  P/S Score.3  Days Before Exam.4  \
# count   3043.000000  3042.000000  3042.000000         3339.000000
# mean     128.400920   128.880342   127.856673           15.078467
# std        2.358199     1.905568     1.745526          673.632574
# min      118.000000   118.000000   118.000000       -32858.000000
# 25%      127.000000   128.000000   127.000000           14.000000
# 50%      129.000000   129.000000   128.000000           22.000000
# 75%      130.000000   130.000000   129.000000           34.000000
# max      132.000000   132.000000   132.000000         6712.000000
#
#        C/P Score.4  CARS Score.4  B/B Score.4  P/S Score.4
# count  3543.000000   3542.000000  3540.000000  3543.000000
# mean    128.332487    127.830604   128.807910   128.001976
# std       2.796926      2.901779    17.048336     6.951981
# min      24.000000     31.000000    29.000000    33.000000
# 25%     127.000000    126.000000   127.000000   127.000000
# 50%     129.000000    128.000000   129.000000   128.000000
# 75%     130.000000    130.000000   130.000000   129.000000
# max     132.000000    132.000000  1130.000000   514.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## Clean Data

# %%
# drop rows with impossible values
#                # days before exam > 180
#                # exact duplicate values to another row
#                # impossible scores (>528 total or >132 on any subsection)
remove_indices = []
remove_indices.extend(scores[scores['Real Score']>528].index.values)
remove_indices.extend(scores[scores['Real Score']<472].index.values)
for i in range(1, 5):
    remove_indices.extend(scores[scores['Days Before Exam.'+str(i)]>200].index.values)
    remove_indices.extend(scores[scores['Days Before Exam.'+str(i)]<0].index.values)
    remove_indices.extend(scores[scores['C/P Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['C/P Score.'+str(i)]<118].index.values)
    remove_indices.extend(scores[scores['CARS Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['CARS Score.'+str(i)]<118].index.values)
    remove_indices.extend(scores[scores['B/B Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['B/B Score.'+str(i)]<118].index.values)
    remove_indices.extend(scores[scores['P/S Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['P/S Score.'+str(i)]<118].index.values)

# remove duplicate indices
remove_indices = list(dict.fromkeys(remove_indices))

# delete all rows with impossible values
for i in remove_indices:
    scores.drop(i, axis = 0, inplace = True)

scores.info()
scores.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4827 entries, 0 to 4995
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Real Score          4779 non-null   float64
#  1   Days Before Exam.1  1690 non-null   float64
#  2   C/P Score.1         1473 non-null   float64
#  3   CARS Score.1        1469 non-null   float64
#  4   B/B Score.1         1467 non-null   float64
#  5   P/S Score.1         1467 non-null   float64
#  6   Days Before Exam.2  2461 non-null   float64
#  7   C/P Score.2         2251 non-null   float64
#  8   CARS Score.2        2250 non-null   float64
#  9   B/B Score.2         2249 non-null   float64
#  10  P/S Score.2         2252 non-null   float64
#  11  Days Before Exam.3  3158 non-null   float64
#  12  C/P Score.3         2935 non-null   float64
#  13  CARS Score.3        2934 non-null   float64
#  14  B/B Score.3         2933 non-null   float64
#  15  P/S Score.3         2933 non-null   float64
#  16  Days Before Exam.4  3188 non-null   float64
#  17  C/P Score.4         3431 non-null   float64
#  18  CARS Score.4        3430 non-null   float64
#  19  B/B Score.4         3428 non-null   float64
#  20  P/S Score.4         3430 non-null   float64
# dtypes: float64(21)
# memory usage: 829.6 KB
#    Real Score  Days Before Exam.1  C/P Score.1  CARS Score.1  B/B Score.1  \
# 0       513.0                 NaN          NaN           NaN          NaN
# 1       495.0                 NaN          NaN           NaN          NaN
# 3       515.0                 7.0        129.0         128.0        128.0
# 4       522.0                 8.0        131.0         129.0        128.0
# 5       524.0                 6.0        131.0         130.0        132.0
#
#    P/S Score.1  Days Before Exam.2  C/P Score.2  CARS Score.2  B/B Score.2  \
# 0          NaN                 5.0        128.0         128.0        129.0
# 1          NaN                 NaN          NaN           NaN          NaN
# 3        130.0                14.0        127.0         126.0        128.0
# 4        131.0                11.0        131.0         128.0        128.0
# 5        131.0                10.0        131.0         127.0        131.0
#
#    ...  Days Before Exam.3  C/P Score.3  CARS Score.3  B/B Score.3  \
# 0  ...                11.0        128.0         128.0        128.0
# 1  ...                 NaN          NaN           NaN          NaN
# 3  ...                21.0        127.0         127.0        129.0
# 4  ...                 4.0        130.0         129.0        130.0
# 5  ...                24.0        132.0         130.0        130.0
#
#    P/S Score.3  Days Before Exam.4  C/P Score.4  CARS Score.4  B/B Score.4  \
# 0        126.0                16.0        127.0         127.0        125.0
# 1          NaN                 NaN          NaN           NaN          NaN
# 3        127.0                28.0        127.0         125.0        127.0
# 4        131.0                15.0        129.0         130.0        129.0
# 5        130.0                90.0        130.0         128.0        130.0
#
#    P/S Score.4
# 0        127.0
# 1          NaN
# 3        127.0
# 4        131.0
# 5        131.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Visualize and Handle Missing Data

# %%
# pip install missingno
import missingno as msno

# visualize missing data with Missingno
msno.bar(scores)
msno.matrix(scores)

# see if there is a reason for missing data
msno.heatmap(scores)
msno.dendrogram(scores)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 # pip install missingno
# ----> 2 import missingno as msno
#       4 # visualize missing data with Missingno
#       5 msno.bar(scores)
#
# ModuleNotFoundError: No module named 'missingno'

# %% [markdown]
# ## Impute Missing Values

# %%
from sklearn.impute import KNNImputer

# Init the transformer
knn_imp = KNNImputer(n_neighbors=3)

# Fit/transform
scores.loc[:, :] = knn_imp.fit_transform(scores)

# %%
# print number of columns, column labels, column data types, memory usage, range index, and non-null number of cells in each column
scores.info()

# preview data
scores.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4827 entries, 0 to 4995
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Real Score          4827 non-null   float64
#  1   Days Before Exam.1  4827 non-null   float64
#  2   C/P Score.1         4827 non-null   float64
#  3   CARS Score.1        4827 non-null   float64
#  4   B/B Score.1         4827 non-null   float64
#  5   P/S Score.1         4827 non-null   float64
#  6   Days Before Exam.2  4827 non-null   float64
#  7   C/P Score.2         4827 non-null   float64
#  8   CARS Score.2        4827 non-null   float64
#  9   B/B Score.2         4827 non-null   float64
#  10  P/S Score.2         4827 non-null   float64
#  11  Days Before Exam.3  4827 non-null   float64
#  12  C/P Score.3         4827 non-null   float64
#  13  CARS Score.3        4827 non-null   float64
#  14  B/B Score.3         4827 non-null   float64
#  15  P/S Score.3         4827 non-null   float64
#  16  Days Before Exam.4  4827 non-null   float64
#  17  C/P Score.4         4827 non-null   float64
#  18  CARS Score.4        4827 non-null   float64
#  19  B/B Score.4         4827 non-null   float64
#  20  P/S Score.4         4827 non-null   float64
# dtypes: float64(21)
# memory usage: 829.6 KB
#    Real Score  Days Before Exam.1  C/P Score.1  CARS Score.1  B/B Score.1  \
# 0       513.0            5.666667   127.666667    127.666667   129.000000
# 1       495.0            2.666667   127.666667    125.333333   129.333333
# 3       515.0            7.000000   129.000000    128.000000   128.000000
# 4       522.0            8.000000   131.000000    129.000000   128.000000
# 5       524.0            6.000000   131.000000    130.000000   132.000000
#
#    P/S Score.1  Days Before Exam.2  C/P Score.2  CARS Score.2  B/B Score.2  \
# 0   128.333333            5.000000   128.000000         128.0   129.000000
# 1   126.000000            3.333333   123.666667         125.0   124.666667
# 3   130.000000           14.000000   127.000000         126.0   128.000000
# 4   131.000000           11.000000   131.000000         128.0   128.000000
# 5   131.000000           10.000000   131.000000         127.0   131.000000
#
#    ...  Days Before Exam.3  C/P Score.3  CARS Score.3  B/B Score.3  \
# 0  ...                11.0   128.000000    128.000000   128.000000
# 1  ...                27.0   125.333333    125.666667   124.666667
# 3  ...                21.0   127.000000    127.000000   129.000000
# 4  ...                 4.0   130.000000    129.000000   130.000000
# 5  ...                24.0   132.000000    130.000000   130.000000
#
#    P/S Score.3  Days Before Exam.4  C/P Score.4  CARS Score.4  B/B Score.4  \
# 0   126.000000           16.000000        127.0    127.000000   125.000000
# 1   124.666667            5.666667        124.0    123.666667   126.666667
# 3   127.000000           28.000000        127.0    125.000000   127.000000
# 4   131.000000           15.000000        129.0    130.000000   129.000000
# 5   130.000000           90.000000        130.0    128.000000   130.000000
#
#    P/S Score.4
# 0        127.0
# 1        125.0
# 3        127.0
# 4        131.0
# 5        131.0
#
# [5 rows x 21 columns]

# %%
# define features and labels from the observations
features = scores.columns[1:len(scores)]
X = scores[features].values.reshape(-1, len(features))
y = scores["Real Score"].to_numpy()
print(X.shape,y.shape)
# Out:
# (4827, 20) (4827,)

# %% [markdown]
# # Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split
from scipy.stats import ks_2samp

#split data into training and testing, fix random_state so output is the same every run
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True,
                                   test_size=0.20, random_state=5)

#We define a function to see if our two sets are distributed evenly for every features
def check_distributions(X1,X2):
    pVals = np.zeros((X1.shape[1]))
    for i in np.arange(X1.shape[1]):
        kstat,pvalue = ks_2samp(X1[:,i],X2[:,i])
        pVals[i]=pvalue
    print("Mean of pvalues :", np.mean(pVals))
    print("Smallest pvalue :",np.amin(pVals)) 
    #return(pVals)

#sanity check: look at how many data points are in train/test and if our pvalues are acceptable
print(X_train.shape[0])
print(X_test.shape[0])
check_distributions(X_train,X_test)
# Out:
# 3861
# 966
# Mean of pvalues : 0.7523720619673906
# Smallest pvalue : 0.1130579326297521

# %% [markdown]
# ## Visualize Correlations

# %%
# create a correlation matrix with pandas
corr_matrix = scores.corr()
corr_matrix['Real Score'].sort_values(ascending=False)

# create scatter matrices displaying totals, medians.
from pandas.plotting import scatter_matrix

attributes = ['Real Score', 'CARS Score.1', 'CARS Score.2', 'CARS Score.3', 'CARS Score.4']
scatter_matrix(scores[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='Real Score', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='Real Score'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.1'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.2'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.3'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.4'>]],
#       dtype=object)

# %% [markdown]
# # Model Validation
# ## Define Model Validation Function

# %%
def model_validation(X, y, results_list, scores_list):
    lin_reg = LinearRegression()
    scoring = "neg_mean_squared_error"
    results_dictionary = cross_validate(lin_reg, X, y, scoring=scoring, cv=4, return_estimator=True)
    results_list.append(results_dictionary)
    mean_score = results_dictionary["test_score"].mean()
    scores_list.append(mean_score)

# %% [markdown]
# ## PCA to Create Linear Combinations of Features

# %%
from sklearn.decomposition import PCA

# fit the PCA
N = 12
pca = PCA(n_components=N)
pca.fit_transform(X_train)

# plot the explained variances
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'tab:blue'
ax1.bar(1+np.arange(N), pca.explained_variance_ratio_, color=color)
ax1.set_xticks(1+np.arange(N, step=2))
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylabel("Explained variance ratio", color=color)
ax1.set_xlabel("Generated feature")

ax2 = ax1.twinx()
color = 'tab:red'
ax2.tick_params(axis='y', labelcolor=color)
ax2.plot(1+np.arange(N), np.cumsum(pca.explained_variance_ratio_), color=color)
ax2.set_ylabel("Cumulative explained variance ratio", color=color)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Train RF Model

# %%
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# Train the model on training data and validate data using k-fold cross validation
scoring = "neg_mean_squared_error"
rf_results_dictionary = cross_validate(rf, X_train, y_train, scoring=scoring, cv=4, return_estimator=True)
rf_mean_score = rf_results_dictionary["test_score"].mean()
print(rf_mean_score)
# Out:
# -4.237834458398327

# %% [markdown]
# ## Visualize the Tree

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(15, 10))
plot_tree(rf.estimators_[0], 
          feature_names = features,
          filled = True, impurity = True, 
          rounded = True)

#from sklearn.tree import export_text

#print(export_text(rf.estimators_[0], 
                  #spacing=3, decimals=3,
                  #feature_names=features))
# Out:
# [Text(0.3700536483373397, 0.975, 'CARS Score.1 <= 127.833\nsquared_error = 48.87\nsamples = 2448\nvalue = 515.515'),
#  Text(0.12593249198717948, 0.925, 'B/B Score.3 <= 126.5\nsquared_error = 43.213\nsamples = 896\nvalue = 509.569'),
#  Text(0.052924679487179487, 0.875, 'B/B Score.4 <= 120.833\nsquared_error = 56.115\nsamples = 241\nvalue = 503.187'),
#  Text(0.038878205128205126, 0.825, 'Days Before Exam.1 <= 5.0\nsquared_error = 35.747\nsamples = 11\nvalue = 483.05'),
#  Text(0.0378525641025641, 0.775, 'squared_error = 0.0\nsamples = 1\nvalue = 487.0'),
#  Text(0.03990384615384615, 0.775, 'squared_error = 36.765\nsamples = 10\nvalue = 482.842'),
#  Text(0.06697115384615385, 0.825, 'P/S Score.1 <= 127.833\nsquared_error = 33.86\nsamples = 230\nvalue = 504.287'),
#  Text(0.04195512820512821, 0.775, 'CARS Score.2 <= 125.5\nsquared_error = 22.087\nsamples = 158\nvalue = 501.973'),
#  Text(0.02294871794871795, 0.725, 'CARS Score.4 <= 123.833\nsquared_error = 19.323\nsamples = 64\nvalue = 498.453'),
#  Text(0.010256410256410256, 0.675, 'B/B Score.1 <= 126.333\nsquared_error = 11.467\nsamples = 36\nvalue = 496.129'),
#  Text(0.0041025641025641026, 0.625, 'CARS Score.3 <= 125.333\nsquared_error = 7.102\nsamples = 5\nvalue = 502.571'),
#  Text(0.0020512820512820513, 0.575, 'Days Before Exam.3 <= 21.5\nsquared_error = 2.25\nsamples = 3\nvalue = 500.5'),
#  Text(0.0010256410256410256, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 499.0'),
#  Text(0.003076923076923077, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 502.0'),
#  Text(0.006153846153846154, 0.575, 'P/S Score.2 <= 128.5\nsquared_error = 0.222\nsamples = 2\nvalue = 505.333'),
#  Text(0.005128205128205128, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.0071794871794871795, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.01641025641025641, 0.625, 'B/B Score.4 <= 125.667\nsquared_error = 6.068\nsamples = 31\nvalue = 495.309'),
#  Text(0.011282051282051283, 0.575, 'Days Before Exam.3 <= 18.0\nsquared_error = 2.032\nsamples = 12\nvalue = 492.667'),
#  Text(0.009230769230769232, 0.525, 'P/S Score.3 <= 122.833\nsquared_error = 0.543\nsamples = 6\nvalue = 494.111'),
#  Text(0.008205128205128205, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 496.0'),
#  Text(0.010256410256410256, 0.475, 'B/B Score.2 <= 123.833\nsquared_error = 0.109\nsamples = 5\nvalue = 493.875'),
#  Text(0.009230769230769232, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 493.0'),
#  Text(0.011282051282051283, 0.425, 'squared_error = 0.0\nsamples = 4\nvalue = 494.0'),
#  Text(0.013333333333333334, 0.525, 'CARS Score.2 <= 124.5\nsquared_error = 0.41\nsamples = 6\nvalue = 491.583'),
#  Text(0.012307692307692308, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 490.0'),
#  Text(0.014358974358974359, 0.475, 'C/P Score.1 <= 126.167\nsquared_error = 0.198\nsamples = 5\nvalue = 491.727'),
#  Text(0.013333333333333334, 0.425, 'squared_error = 0.16\nsamples = 4\nvalue = 491.8'),
#  Text(0.015384615384615385, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 491.0'),
#  Text(0.021538461538461538, 0.575, 'Days Before Exam.1 <= 4.333\nsquared_error = 1.585\nsamples = 19\nvalue = 496.941'),
#  Text(0.019487179487179488, 0.525, 'CARS Score.1 <= 125.667\nsquared_error = 0.737\nsamples = 12\nvalue = 496.0'),
#  Text(0.018461538461538463, 0.475, 'Days Before Exam.1 <= 3.167\nsquared_error = 0.243\nsamples = 8\nvalue = 495.417'),
#  Text(0.017435897435897435, 0.425, 'squared_error = 0.0\nsamples = 5\nvalue = 495.0'),
#  Text(0.019487179487179488, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 496.0'),
#  Text(0.020512820512820513, 0.475, 'squared_error = 0.0\nsamples = 4\nvalue = 497.0'),
#  Text(0.02358974358974359, 0.525, 'P/S Score.2 <= 123.0\nsquared_error = 0.116\nsamples = 7\nvalue = 498.133'),
#  Text(0.022564102564102566, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 499.0'),
#  Text(0.024615384615384615, 0.475, 'squared_error = 0.0\nsamples = 6\nvalue = 498.0'),
#  Text(0.03564102564102564, 0.675, 'CARS Score.1 <= 125.333\nsquared_error = 12.062\nsamples = 28\nvalue = 501.727'),
#  Text(0.03076923076923077, 0.625, 'P/S Score.4 <= 125.5\nsquared_error = 4.918\nsamples = 9\nvalue = 504.714'),
#  Text(0.028717948717948718, 0.575, 'CARS Score.3 <= 124.833\nsquared_error = 2.583\nsamples = 4\nvalue = 502.5'),
#  Text(0.027692307692307693, 0.525, 'CARS Score.4 <= 126.333\nsquared_error = 0.16\nsamples = 3\nvalue = 503.2'),
#  Text(0.02666666666666667, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 503.0'),
#  Text(0.028717948717948718, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 504.0'),
#  Text(0.029743589743589743, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 499.0'),
#  Text(0.03282051282051282, 0.575, 'CARS Score.2 <= 124.5\nsquared_error = 0.234\nsamples = 5\nvalue = 506.375'),
#  Text(0.031794871794871796, 0.525, 'B/B Score.4 <= 125.5\nsquared_error = 0.188\nsamples = 3\nvalue = 506.75'),
#  Text(0.03076923076923077, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 507.0'),
#  Text(0.03282051282051282, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.033846153846153845, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 506.0'),
#  Text(0.04051282051282051, 0.625, 'C/P Score.1 <= 127.667\nsquared_error = 9.289\nsamples = 19\nvalue = 500.333'),
#  Text(0.03794871794871795, 0.575, 'Days Before Exam.1 <= 6.5\nsquared_error = 6.004\nsamples = 17\nvalue = 499.821'),
#  Text(0.035897435897435895, 0.525, 'Days Before Exam.2 <= 6.333\nsquared_error = 2.88\nsamples = 14\nvalue = 499.2'),
#  Text(0.03487179487179487, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 495.0'),
#  Text(0.036923076923076927, 0.475, 'C/P Score.2 <= 124.5\nsquared_error = 1.463\nsamples = 12\nvalue = 499.565'),
#  Text(0.035897435897435895, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 504.0'),
#  Text(0.03794871794871795, 0.425, 'P/S Score.1 <= 125.167\nsquared_error = 0.595\nsamples = 11\nvalue = 499.364'),
#  Text(0.035897435897435895, 0.375, 'C/P Score.3 <= 126.5\nsquared_error = 0.071\nsamples = 6\nvalue = 499.923'),
#  Text(0.03487179487179487, 0.325, 'squared_error = 0.0\nsamples = 5\nvalue = 500.0'),
#  Text(0.036923076923076927, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 499.0'),
#  Text(0.04, 0.375, 'Days Before Exam.1 <= 5.0\nsquared_error = 0.247\nsamples = 5\nvalue = 498.556'),
#  Text(0.038974358974358976, 0.325, 'squared_error = 0.0\nsamples = 3\nvalue = 499.0'),
#  Text(0.041025641025641026, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 498.0'),
#  Text(0.04, 0.525, 'CARS Score.2 <= 125.167\nsquared_error = 2.0\nsamples = 3\nvalue = 505.0'),
#  Text(0.038974358974358976, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 506.0'),
#  Text(0.041025641025641026, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 503.0'),
#  Text(0.043076923076923075, 0.575, 'Days Before Exam.3 <= 15.0\nsquared_error = 0.25\nsamples = 2\nvalue = 507.5'),
#  Text(0.04205128205128205, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.0441025641025641, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.06096153846153846, 0.725, 'C/P Score.1 <= 125.833\nsquared_error = 9.707\nsamples = 94\nvalue = 504.381'),
#  Text(0.05282051282051282, 0.675, 'C/P Score.3 <= 126.167\nsquared_error = 4.307\nsamples = 30\nvalue = 501.245'),
#  Text(0.04923076923076923, 0.625, 'C/P Score.1 <= 124.833\nsquared_error = 0.996\nsamples = 27\nvalue = 500.733'),
#  Text(0.04717948717948718, 0.575, 'C/P Score.2 <= 123.667\nsquared_error = 0.16\nsamples = 15\nvalue = 499.917'),
#  Text(0.046153846153846156, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 498.0'),
#  Text(0.048205128205128206, 0.525, 'squared_error = 0.0\nsamples = 14\nvalue = 500.0'),
#  Text(0.05128205128205128, 0.575, 'Days Before Exam.4 <= 34.833\nsquared_error = 0.317\nsamples = 12\nvalue = 501.667'),
#  Text(0.050256410256410255, 0.525, 'squared_error = 0.0\nsamples = 5\nvalue = 501.0'),
#  Text(0.052307692307692305, 0.525, 'C/P Score.3 <= 124.5\nsquared_error = 0.071\nsamples = 7\nvalue = 502.077'),
#  Text(0.05128205128205128, 0.475, 'squared_error = 0.0\nsamples = 6\nvalue = 502.0'),
#  Text(0.05333333333333334, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 503.0'),
#  Text(0.05641025641025641, 0.625, 'C/P Score.2 <= 127.167\nsquared_error = 5.5\nsamples = 3\nvalue = 507.0'),
#  Text(0.055384615384615386, 0.575, 'B/B Score.1 <= 125.5\nsquared_error = 0.222\nsamples = 2\nvalue = 505.667'),
#  Text(0.05435897435897436, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.05641025641025641, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.057435897435897436, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.0691025641025641, 0.675, 'CARS Score.2 <= 126.833\nsquared_error = 5.556\nsamples = 64\nvalue = 505.83'),
#  Text(0.06384615384615384, 0.625, 'B/B Score.1 <= 127.167\nsquared_error = 2.873\nsamples = 44\nvalue = 504.831'),
#  Text(0.06, 0.575, 'CARS Score.1 <= 127.167\nsquared_error = 0.861\nsamples = 30\nvalue = 504.039'),
#  Text(0.05897435897435897, 0.525, 'CARS Score.4 <= 124.5\nsquared_error = 0.524\nsamples = 29\nvalue = 503.918'),
#  Text(0.055384615384615386, 0.475, 'CARS Score.3 <= 123.167\nsquared_error = 0.597\nsamples = 10\nvalue = 503.214'),
#  Text(0.05435897435897436, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 501.0'),
#  Text(0.05641025641025641, 0.425, 'CARS Score.3 <= 124.833\nsquared_error = 0.237\nsamples = 9\nvalue = 503.385'),
#  Text(0.055384615384615386, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 504.0'),
#  Text(0.057435897435897436, 0.375, 'squared_error = 0.0\nsamples = 8\nvalue = 503.0'),
#  Text(0.06256410256410257, 0.475, 'P/S Score.3 <= 126.0\nsquared_error = 0.217\nsamples = 19\nvalue = 504.2'),
#  Text(0.06051282051282051, 0.425, 'P/S Score.1 <= 126.833\nsquared_error = 0.032\nsamples = 16\nvalue = 504.033'),
#  Text(0.059487179487179485, 0.375, 'squared_error = 0.0\nsamples = 15\nvalue = 504.0'),
#  Text(0.06153846153846154, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.06461538461538462, 0.425, 'CARS Score.3 <= 127.0\nsquared_error = 0.16\nsamples = 3\nvalue = 505.2'),
#  Text(0.06358974358974359, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 505.0'),
#  Text(0.06564102564102564, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.06102564102564102, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.06769230769230769, 0.575, 'Days Before Exam.4 <= 73.167\nsquared_error = 2.327\nsamples = 14\nvalue = 506.85'),
#  Text(0.06666666666666667, 0.525, 'Days Before Exam.1 <= 5.333\nsquared_error = 0.756\nsamples = 13\nvalue = 507.278'),
#  Text(0.06564102564102564, 0.475, 'squared_error = 0.0\nsamples = 7\nvalue = 508.0'),
#  Text(0.06769230769230769, 0.475, 'B/B Score.3 <= 125.833\nsquared_error = 0.234\nsamples = 6\nvalue = 506.375'),
#  Text(0.06666666666666667, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 507.0'),
#  Text(0.06871794871794872, 0.425, 'squared_error = 0.0\nsamples = 4\nvalue = 506.0'),
#  Text(0.06871794871794872, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 503.0'),
#  Text(0.07435897435897436, 0.625, 'Days Before Exam.2 <= 5.0\nsquared_error = 4.865\nsamples = 20\nvalue = 507.857'),
#  Text(0.07179487179487179, 0.575, 'C/P Score.4 <= 126.167\nsquared_error = 1.901\nsamples = 5\nvalue = 506.091'),
#  Text(0.07076923076923076, 0.525, 'P/S Score.4 <= 124.5\nsquared_error = 0.359\nsamples = 4\nvalue = 506.875'),
#  Text(0.06974358974358974, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.07179487179487179, 0.475, 'Days Before Exam.1 <= 5.667\nsquared_error = 0.139\nsamples = 3\nvalue = 507.167'),
#  Text(0.07076923076923076, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.07282051282051281, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 507.0'),
#  Text(0.07282051282051281, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 504.0'),
#  Text(0.07692307692307693, 0.575, 'P/S Score.1 <= 127.333\nsquared_error = 4.139\nsamples = 15\nvalue = 508.667'),
#  Text(0.07487179487179488, 0.525, 'P/S Score.3 <= 124.5\nsquared_error = 1.136\nsamples = 9\nvalue = 510.308'),
#  Text(0.07384615384615385, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.0758974358974359, 0.475, 'squared_error = 0.0\nsamples = 8\nvalue = 510.0'),
#  Text(0.07897435897435898, 0.525, 'P/S Score.4 <= 125.5\nsquared_error = 0.744\nsamples = 6\nvalue = 506.727'),
#  Text(0.07794871794871795, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.08, 0.475, 'B/B Score.2 <= 127.833\nsquared_error = 0.099\nsamples = 5\nvalue = 507.111'),
#  Text(0.07897435897435898, 0.425, 'squared_error = 0.0\nsamples = 4\nvalue = 507.0'),
#  Text(0.08102564102564103, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.0919871794871795, 0.775, 'CARS Score.4 <= 122.833\nsquared_error = 16.741\nsamples = 72\nvalue = 510.038'),
#  Text(0.0835897435897436, 0.725, 'B/B Score.1 <= 125.833\nsquared_error = 8.694\nsamples = 5\nvalue = 501.143'),
#  Text(0.08256410256410257, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 497.0'),
#  Text(0.08461538461538462, 0.675, 'CARS Score.2 <= 125.833\nsquared_error = 2.56\nsamples = 4\nvalue = 502.8'),
#  Text(0.0835897435897436, 0.625, 'squared_error = 0.0\nsamples = 3\nvalue = 502.0'),
#  Text(0.08564102564102564, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.10038461538461538, 0.725, 'C/P Score.1 <= 129.167\nsquared_error = 11.261\nsamples = 67\nvalue = 510.673'),
#  Text(0.09307692307692307, 0.675, 'B/B Score.2 <= 126.833\nsquared_error = 8.293\nsamples = 61\nvalue = 510.101'),
#  Text(0.0876923076923077, 0.625, 'P/S Score.1 <= 128.667\nsquared_error = 12.617\nsamples = 12\nvalue = 507.222'),
#  Text(0.08512820512820513, 0.575, 'P/S Score.2 <= 127.333\nsquared_error = 6.139\nsamples = 9\nvalue = 505.167'),
#  Text(0.08307692307692308, 0.525, 'Days Before Exam.1 <= 5.667\nsquared_error = 2.734\nsamples = 6\nvalue = 506.625'),
#  Text(0.08205128205128205, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.0841025641025641, 0.475, 'squared_error = 0.0\nsamples = 5\nvalue = 506.0'),
#  Text(0.08717948717948718, 0.525, 'B/B Score.3 <= 125.667\nsquared_error = 0.188\nsamples = 3\nvalue = 502.25'),
#  Text(0.08615384615384615, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 502.0'),
#  Text(0.0882051282051282, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 503.0'),
#  Text(0.09025641025641026, 0.575, 'P/S Score.4 <= 125.0\nsquared_error = 0.222\nsamples = 3\nvalue = 511.333'),
#  Text(0.08923076923076922, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.09128205128205129, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 511.0'),
#  Text(0.09846153846153846, 0.625, 'Days Before Exam.1 <= 5.333\nsquared_error = 4.563\nsamples = 49\nvalue = 510.831'),
#  Text(0.09435897435897436, 0.575, 'Days Before Exam.1 <= 1.5\nsquared_error = 3.679\nsamples = 29\nvalue = 509.744'),
#  Text(0.09333333333333334, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.09538461538461539, 0.525, 'C/P Score.1 <= 127.333\nsquared_error = 2.105\nsamples = 28\nvalue = 509.548'),
#  Text(0.09333333333333334, 0.475, 'B/B Score.1 <= 126.333\nsquared_error = 1.5\nsamples = 8\nvalue = 511.0'),
#  Text(0.09230769230769231, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.09435897435897436, 0.425, 'Days Before Exam.1 <= 4.167\nsquared_error = 0.744\nsamples = 7\nvalue = 511.273'),
#  Text(0.09333333333333334, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.09538461538461539, 0.375, 'squared_error = 0.0\nsamples = 6\nvalue = 511.0'),
#  Text(0.09743589743589744, 0.475, 'P/S Score.3 <= 125.5\nsquared_error = 1.166\nsamples = 20\nvalue = 508.967'),
#  Text(0.09641025641025641, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 504.0'),
#  Text(0.09846153846153846, 0.425, 'B/B Score.1 <= 127.167\nsquared_error = 0.326\nsamples = 19\nvalue = 509.138'),
#  Text(0.09743589743589744, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.09948717948717949, 0.375, 'C/P Score.2 <= 128.833\nsquared_error = 0.034\nsamples = 18\nvalue = 509.036'),
#  Text(0.09846153846153846, 0.325, 'squared_error = 0.0\nsamples = 17\nvalue = 509.0'),
#  Text(0.10051282051282051, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.10256410256410256, 0.575, 'B/B Score.1 <= 125.5\nsquared_error = 1.321\nsamples = 20\nvalue = 512.5'),
#  Text(0.10153846153846154, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.10358974358974359, 0.525, 'Days Before Exam.2 <= 13.5\nsquared_error = 0.9\nsamples = 19\nvalue = 512.63'),
#  Text(0.10153846153846154, 0.475, 'CARS Score.1 <= 126.833\nsquared_error = 0.24\nsamples = 17\nvalue = 512.4'),
#  Text(0.10051282051282051, 0.425, 'squared_error = 0.0\nsamples = 10\nvalue = 512.0'),
#  Text(0.10256410256410256, 0.425, 'squared_error = 0.0\nsamples = 7\nvalue = 513.0'),
#  Text(0.10564102564102563, 0.475, 'C/P Score.4 <= 126.667\nsquared_error = 0.25\nsamples = 2\nvalue = 515.5'),
#  Text(0.10461538461538461, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.10666666666666667, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.1076923076923077, 0.675, 'CARS Score.2 <= 125.5\nsquared_error = 5.333\nsamples = 6\nvalue = 516.333'),
#  Text(0.10564102564102563, 0.625, 'Days Before Exam.1 <= 5.5\nsquared_error = 1.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.10461538461538461, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.10666666666666667, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.10974358974358975, 0.625, 'P/S Score.3 <= 128.5\nsquared_error = 2.49\nsamples = 4\nvalue = 517.286'),
#  Text(0.10871794871794872, 0.575, 'Days Before Exam.3 <= 11.0\nsquared_error = 0.222\nsamples = 3\nvalue = 516.667'),
#  Text(0.1076923076923077, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.10974358974358975, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 517.0'),
#  Text(0.11076923076923077, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.19894030448717948, 0.875, 'P/S Score.1 <= 127.833\nsquared_error = 17.962\nsamples = 655\nvalue = 511.917'),
#  Text(0.14155448717948718, 0.825, 'CARS Score.2 <= 125.833\nsquared_error = 14.539\nsamples = 235\nvalue = 508.992'),
#  Text(0.12243589743589743, 0.775, 'C/P Score.1 <= 124.5\nsquared_error = 10.169\nsamples = 66\nvalue = 506.346'),
#  Text(0.11743589743589744, 0.725, 'Days Before Exam.3 <= 17.0\nsquared_error = 9.0\nsamples = 2\nvalue = 496.0'),
#  Text(0.11641025641025642, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 499.0'),
#  Text(0.11846153846153847, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 493.0'),
#  Text(0.12743589743589745, 0.725, 'P/S Score.1 <= 127.5\nsquared_error = 8.052\nsamples = 64\nvalue = 506.549'),
#  Text(0.12051282051282051, 0.675, 'CARS Score.1 <= 123.833\nsquared_error = 5.365\nsamples = 44\nvalue = 507.703'),
#  Text(0.11948717948717949, 0.625, 'squared_error = 0.0\nsamples = 4\nvalue = 504.0'),
#  Text(0.12153846153846154, 0.625, 'B/B Score.1 <= 128.333\nsquared_error = 3.893\nsamples = 40\nvalue = 508.232'),
#  Text(0.1158974358974359, 0.575, 'P/S Score.1 <= 126.167\nsquared_error = 6.207\nsamples = 17\nvalue = 509.154'),
#  Text(0.1117948717948718, 0.525, 'B/B Score.3 <= 127.5\nsquared_error = 3.021\nsamples = 7\nvalue = 507.25'),
#  Text(0.10974358974358975, 0.475, 'B/B Score.1 <= 127.5\nsquared_error = 0.857\nsamples = 4\nvalue = 506.0'),
#  Text(0.10871794871794872, 0.425, 'B/B Score.3 <= 126.833\nsquared_error = 0.188\nsamples = 3\nvalue = 505.25'),
#  Text(0.1076923076923077, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.10974358974358975, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 505.0'),
#  Text(0.11076923076923077, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.11384615384615385, 0.475, 'Days Before Exam.1 <= 13.5\nsquared_error = 0.8\nsamples = 3\nvalue = 509.0'),
#  Text(0.11282051282051282, 0.425, 'Days Before Exam.2 <= 7.5\nsquared_error = 0.222\nsamples = 2\nvalue = 508.333'),
#  Text(0.1117948717948718, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.11384615384615385, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.11487179487179487, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.12, 0.525, 'C/P Score.1 <= 128.5\nsquared_error = 3.168\nsamples = 10\nvalue = 510.786'),
#  Text(0.11794871794871795, 0.475, 'CARS Score.3 <= 128.333\nsquared_error = 1.355\nsamples = 7\nvalue = 510.091'),
#  Text(0.11692307692307692, 0.425, 'CARS Score.4 <= 125.5\nsquared_error = 0.44\nsamples = 6\nvalue = 510.4'),
#  Text(0.1158974358974359, 0.375, 'C/P Score.4 <= 125.833\nsquared_error = 0.222\nsamples = 2\nvalue = 511.333'),
#  Text(0.11487179487179487, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.11692307692307692, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.11794871794871795, 0.375, 'squared_error = 0.0\nsamples = 4\nvalue = 510.0'),
#  Text(0.11897435897435897, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.12205128205128205, 0.475, 'P/S Score.4 <= 124.5\nsquared_error = 1.556\nsamples = 3\nvalue = 513.333'),
#  Text(0.12102564102564102, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.12307692307692308, 0.425, 'B/B Score.1 <= 127.5\nsquared_error = 0.25\nsamples = 2\nvalue = 512.5'),
#  Text(0.12205128205128205, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.12410256410256411, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.12717948717948718, 0.575, 'P/S Score.2 <= 127.667\nsquared_error = 0.512\nsamples = 23\nvalue = 507.433'),
#  Text(0.12512820512820513, 0.525, 'CARS Score.2 <= 124.5\nsquared_error = 0.184\nsamples = 13\nvalue = 507.938'),
#  Text(0.12410256410256411, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 507.0'),
#  Text(0.12615384615384614, 0.475, 'P/S Score.2 <= 125.667\nsquared_error = 0.066\nsamples = 11\nvalue = 508.071'),
#  Text(0.12512820512820513, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.12717948717948718, 0.425, 'squared_error = 0.0\nsamples = 10\nvalue = 508.0'),
#  Text(0.12923076923076923, 0.525, 'Days Before Exam.4 <= 26.5\nsquared_error = 0.265\nsamples = 10\nvalue = 506.857'),
#  Text(0.1282051282051282, 0.475, 'squared_error = 0.0\nsamples = 9\nvalue = 507.0'),
#  Text(0.13025641025641024, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.13435897435897437, 0.675, 'CARS Score.4 <= 123.5\nsquared_error = 6.555\nsamples = 20\nvalue = 504.605'),
#  Text(0.13333333333333333, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 496.0'),
#  Text(0.13538461538461538, 0.625, 'CARS Score.1 <= 126.167\nsquared_error = 2.576\nsamples = 19\nvalue = 505.083'),
#  Text(0.13435897435897437, 0.575, 'B/B Score.1 <= 128.0\nsquared_error = 0.73\nsamples = 18\nvalue = 505.314'),
#  Text(0.13333333333333333, 0.525, 'Days Before Exam.1 <= 8.167\nsquared_error = 0.059\nsamples = 16\nvalue = 505.062'),
#  Text(0.13230769230769232, 0.475, 'squared_error = 0.0\nsamples = 14\nvalue = 505.0'),
#  Text(0.13435897435897437, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 506.0'),
#  Text(0.13538461538461538, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 508.0'),
#  Text(0.13641025641025642, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 497.0'),
#  Text(0.16067307692307692, 0.775, 'B/B Score.2 <= 129.167\nsquared_error = 12.704\nsamples = 169\nvalue = 509.938'),
#  Text(0.14506410256410257, 0.725, 'B/B Score.1 <= 124.667\nsquared_error = 10.925\nsamples = 156\nvalue = 509.579'),
#  Text(0.13846153846153847, 0.675, 'Days Before Exam.3 <= 12.333\nsquared_error = 14.25\nsamples = 3\nvalue = 502.5'),
#  Text(0.13743589743589743, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.13948717948717948, 0.625, 'P/S Score.3 <= 126.5\nsquared_error = 0.222\nsamples = 2\nvalue = 500.333'),
#  Text(0.13846153846153847, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 501.0'),
#  Text(0.14051282051282052, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 500.0'),
#  Text(0.15166666666666667, 0.675, 'Days Before Exam.2 <= 1.5\nsquared_error = 9.266\nsamples = 153\nvalue = 509.792'),
#  Text(0.15064102564102563, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 492.0'),
#  Text(0.15269230769230768, 0.625, 'CARS Score.2 <= 126.833\nsquared_error = 8.098\nsamples = 152\nvalue = 509.86'),
#  Text(0.14256410256410257, 0.575, 'C/P Score.2 <= 128.833\nsquared_error = 5.91\nsamples = 77\nvalue = 508.713'),
#  Text(0.13807692307692307, 0.525, 'C/P Score.1 <= 124.667\nsquared_error = 3.708\nsamples = 73\nvalue = 508.369'),
#  Text(0.13705128205128206, 0.475, 'squared_error = 0.0\nsamples = 17\nvalue = 511.0'),
#  Text(0.1391025641025641, 0.475, 'CARS Score.4 <= 124.5\nsquared_error = 1.924\nsamples = 56\nvalue = 507.511'),
#  Text(0.1332051282051282, 0.425, 'CARS Score.3 <= 124.833\nsquared_error = 2.007\nsamples = 11\nvalue = 505.588'),
#  Text(0.13115384615384615, 0.375, 'P/S Score.2 <= 126.833\nsquared_error = 0.469\nsamples = 6\nvalue = 504.444'),
#  Text(0.13012820512820514, 0.325, 'B/B Score.2 <= 127.833\nsquared_error = 0.222\nsamples = 2\nvalue = 505.333'),
#  Text(0.1291025641025641, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.13115384615384615, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.1321794871794872, 0.325, 'squared_error = 0.0\nsamples = 4\nvalue = 504.0'),
#  Text(0.13525641025641025, 0.375, 'P/S Score.4 <= 125.5\nsquared_error = 0.609\nsamples = 5\nvalue = 506.875'),
#  Text(0.13423076923076924, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.1362820512820513, 0.325, 'C/P Score.4 <= 126.667\nsquared_error = 0.24\nsamples = 4\nvalue = 507.4'),
#  Text(0.13525641025641025, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 507.0'),
#  Text(0.1373076923076923, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 508.0'),
#  Text(0.145, 0.425, 'Days Before Exam.4 <= 58.167\nsquared_error = 0.877\nsamples = 45\nvalue = 507.947'),
#  Text(0.14243589743589744, 0.375, 'C/P Score.2 <= 127.167\nsquared_error = 0.438\nsamples = 31\nvalue = 507.472'),
#  Text(0.14038461538461539, 0.325, 'C/P Score.4 <= 124.5\nsquared_error = 0.249\nsamples = 17\nvalue = 507.964'),
#  Text(0.13935897435897435, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.14141025641025642, 0.275, 'C/P Score.1 <= 126.5\nsquared_error = 0.109\nsamples = 16\nvalue = 508.125'),
#  Text(0.14038461538461539, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.14243589743589744, 0.225, 'squared_error = 0.0\nsamples = 15\nvalue = 508.0'),
#  Text(0.14448717948717948, 0.325, 'C/P Score.3 <= 126.5\nsquared_error = 0.074\nsamples = 14\nvalue = 506.92'),
#  Text(0.14346153846153847, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 506.0'),
#  Text(0.14551282051282052, 0.275, 'squared_error = 0.0\nsamples = 12\nvalue = 507.0'),
#  Text(0.14756410256410257, 0.375, 'C/P Score.4 <= 127.0\nsquared_error = 0.083\nsamples = 14\nvalue = 509.091'),
#  Text(0.14653846153846153, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.14858974358974358, 0.325, 'squared_error = 0.0\nsamples = 13\nvalue = 509.0'),
#  Text(0.14705128205128204, 0.525, 'B/B Score.3 <= 127.833\nsquared_error = 6.204\nsamples = 4\nvalue = 514.714'),
#  Text(0.14602564102564103, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.14807692307692308, 0.475, 'C/P Score.3 <= 128.0\nsquared_error = 0.96\nsamples = 3\nvalue = 516.2'),
#  Text(0.14705128205128204, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.1491025641025641, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.16282051282051282, 0.575, 'C/P Score.1 <= 128.667\nsquared_error = 7.731\nsamples = 75\nvalue = 510.956'),
#  Text(0.1580769230769231, 0.525, 'Days Before Exam.4 <= 60.5\nsquared_error = 2.92\nsamples = 67\nvalue = 510.283'),
#  Text(0.15474358974358973, 0.475, 'B/B Score.1 <= 127.667\nsquared_error = 1.538\nsamples = 65\nvalue = 510.094'),
#  Text(0.15115384615384617, 0.425, 'Days Before Exam.2 <= 2.5\nsquared_error = 0.646\nsamples = 57\nvalue = 510.413'),
#  Text(0.15012820512820513, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.15217948717948718, 0.375, 'C/P Score.1 <= 126.167\nsquared_error = 0.238\nsamples = 56\nvalue = 510.324'),
#  Text(0.15115384615384617, 0.325, 'squared_error = 0.0\nsamples = 16\nvalue = 511.0'),
#  Text(0.15320512820512822, 0.325, 'Days Before Exam.1 <= 2.5\nsquared_error = 0.014\nsamples = 40\nvalue = 509.985'),
#  Text(0.15217948717948718, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.15423076923076923, 0.275, 'squared_error = 0.0\nsamples = 39\nvalue = 510.0'),
#  Text(0.15833333333333333, 0.425, 'CARS Score.3 <= 126.833\nsquared_error = 1.325\nsamples = 8\nvalue = 507.538'),
#  Text(0.15628205128205128, 0.375, 'CARS Score.4 <= 126.0\nsquared_error = 0.25\nsamples = 4\nvalue = 508.5'),
#  Text(0.15525641025641027, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 509.0'),
#  Text(0.15730769230769232, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 508.0'),
#  Text(0.16038461538461538, 0.375, 'B/B Score.2 <= 127.5\nsquared_error = 0.776\nsamples = 4\nvalue = 506.714'),
#  Text(0.15935897435897436, 0.325, 'B/B Score.4 <= 129.0\nsquared_error = 0.222\nsamples = 2\nvalue = 507.667'),
#  Text(0.15833333333333333, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.16038461538461538, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.16141025641025641, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 506.0'),
#  Text(0.16141025641025641, 0.475, 'B/B Score.4 <= 126.333\nsquared_error = 0.889\nsamples = 2\nvalue = 517.667'),
#  Text(0.16038461538461538, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.16243589743589743, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.16756410256410256, 0.525, 'Days Before Exam.1 <= 4.0\nsquared_error = 13.689\nsamples = 8\nvalue = 516.333'),
#  Text(0.1655128205128205, 0.475, 'C/P Score.3 <= 127.0\nsquared_error = 1.688\nsamples = 3\nvalue = 519.25'),
#  Text(0.16448717948717947, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.16653846153846155, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 520.0'),
#  Text(0.1696153846153846, 0.475, 'B/B Score.2 <= 126.667\nsquared_error = 6.571\nsamples = 5\nvalue = 513.0'),
#  Text(0.1685897435897436, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.17064102564102565, 0.425, 'P/S Score.2 <= 128.0\nsquared_error = 0.24\nsamples = 4\nvalue = 514.6'),
#  Text(0.1696153846153846, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.17166666666666666, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.1762820512820513, 0.725, 'Days Before Exam.1 <= 10.5\nsquared_error = 8.015\nsamples = 13\nvalue = 515.389'),
#  Text(0.1737179487179487, 0.675, 'B/B Score.4 <= 128.5\nsquared_error = 5.673\nsamples = 10\nvalue = 514.429'),
#  Text(0.17166666666666666, 0.625, 'Days Before Exam.3 <= 18.833\nsquared_error = 8.667\nsamples = 3\nvalue = 511.0'),
#  Text(0.17064102564102565, 0.575, 'P/S Score.1 <= 126.833\nsquared_error = 1.0\nsamples = 2\nvalue = 509.0'),
#  Text(0.1696153846153846, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.17166666666666666, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.1726923076923077, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.17576923076923076, 0.625, 'Days Before Exam.4 <= 32.833\nsquared_error = 0.777\nsamples = 7\nvalue = 515.364'),
#  Text(0.17474358974358975, 0.575, 'Days Before Exam.1 <= 4.0\nsquared_error = 0.09\nsamples = 6\nvalue = 515.1'),
#  Text(0.1737179487179487, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.17576923076923076, 0.525, 'squared_error = 0.0\nsamples = 5\nvalue = 515.0'),
#  Text(0.1767948717948718, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.17884615384615385, 0.675, 'P/S Score.2 <= 128.5\nsquared_error = 1.688\nsamples = 3\nvalue = 518.75'),
#  Text(0.1778205128205128, 0.625, 'squared_error = 0.0\nsamples = 2\nvalue = 518.0'),
#  Text(0.17987179487179486, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.2563261217948718, 0.825, 'C/P Score.2 <= 128.5\nsquared_error = 11.742\nsamples = 420\nvalue = 513.683'),
#  Text(0.21631410256410255, 0.775, 'CARS Score.1 <= 126.5\nsquared_error = 8.072\nsamples = 192\nvalue = 511.708'),
#  Text(0.19814102564102565, 0.725, 'P/S Score.4 <= 126.5\nsquared_error = 6.445\nsamples = 79\nvalue = 509.782'),
#  Text(0.18653846153846154, 0.675, 'B/B Score.2 <= 127.333\nsquared_error = 3.716\nsamples = 25\nvalue = 507.769'),
#  Text(0.1819230769230769, 0.625, 'Days Before Exam.3 <= 21.833\nsquared_error = 1.248\nsamples = 13\nvalue = 506.455'),
#  Text(0.17987179487179486, 0.575, 'CARS Score.3 <= 124.5\nsquared_error = 0.234\nsamples = 4\nvalue = 507.625'),
#  Text(0.17884615384615385, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.1808974358974359, 0.525, 'squared_error = 0.0\nsamples = 3\nvalue = 508.0'),
#  Text(0.183974358974359, 0.575, 'P/S Score.2 <= 127.333\nsquared_error = 0.597\nsamples = 9\nvalue = 505.786'),
#  Text(0.18294871794871795, 0.525, 'squared_error = 0.0\nsamples = 8\nvalue = 506.0'),
#  Text(0.185, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 503.0'),
#  Text(0.19115384615384615, 0.625, 'C/P Score.3 <= 128.333\nsquared_error = 1.779\nsamples = 12\nvalue = 509.471'),
#  Text(0.18807692307692309, 0.575, 'CARS Score.1 <= 125.5\nsquared_error = 0.923\nsamples = 8\nvalue = 509.0'),
#  Text(0.18705128205128205, 0.525, 'squared_error = 0.0\nsamples = 3\nvalue = 510.0'),
#  Text(0.1891025641025641, 0.525, 'P/S Score.1 <= 128.5\nsquared_error = 0.484\nsamples = 5\nvalue = 508.375'),
#  Text(0.18807692307692309, 0.475, 'CARS Score.3 <= 123.5\nsquared_error = 0.188\nsamples = 3\nvalue = 507.75'),
#  Text(0.18705128205128205, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.1891025641025641, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 508.0'),
#  Text(0.19012820512820514, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 509.0'),
#  Text(0.19423076923076923, 0.575, 'B/B Score.2 <= 129.667\nsquared_error = 1.5\nsamples = 4\nvalue = 511.0'),
#  Text(0.1932051282051282, 0.525, 'Days Before Exam.2 <= 15.0\nsquared_error = 0.222\nsamples = 3\nvalue = 511.667'),
#  Text(0.19217948717948719, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 512.0'),
#  Text(0.19423076923076923, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.19525641025641025, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.20974358974358975, 0.675, 'CARS Score.1 <= 126.167\nsquared_error = 4.984\nsamples = 54\nvalue = 510.706'),
#  Text(0.20576923076923076, 0.625, 'CARS Score.2 <= 129.0\nsquared_error = 7.305\nsamples = 26\nvalue = 512.105'),
#  Text(0.2008974358974359, 0.575, 'B/B Score.4 <= 128.5\nsquared_error = 5.17\nsamples = 22\nvalue = 511.647'),
#  Text(0.1973076923076923, 0.525, 'B/B Score.4 <= 126.333\nsquared_error = 4.394\nsamples = 16\nvalue = 510.92'),
#  Text(0.19628205128205128, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.19833333333333333, 0.475, 'Days Before Exam.1 <= 11.0\nsquared_error = 2.972\nsamples = 15\nvalue = 510.667'),
#  Text(0.1973076923076923, 0.425, 'CARS Score.2 <= 127.667\nsquared_error = 2.831\nsamples = 12\nvalue = 511.105'),
#  Text(0.19628205128205128, 0.375, 'Days Before Exam.3 <= 15.0\nsquared_error = 1.17\nsamples = 10\nvalue = 510.647'),
#  Text(0.1926923076923077, 0.325, 'P/S Score.4 <= 127.667\nsquared_error = 0.694\nsamples = 4\nvalue = 509.857'),
#  Text(0.19166666666666668, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 509.0'),
#  Text(0.19371794871794873, 0.275, 'CARS Score.2 <= 124.833\nsquared_error = 0.25\nsamples = 2\nvalue = 510.5'),
#  Text(0.1926923076923077, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.19474358974358974, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.19987179487179488, 0.325, 'P/S Score.4 <= 127.5\nsquared_error = 0.76\nsamples = 6\nvalue = 511.2'),
#  Text(0.19782051282051283, 0.275, 'P/S Score.2 <= 129.5\nsquared_error = 0.222\nsamples = 3\nvalue = 510.667'),
#  Text(0.1967948717948718, 0.225, 'squared_error = 0.0\nsamples = 2\nvalue = 511.0'),
#  Text(0.19884615384615384, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.20192307692307693, 0.275, 'C/P Score.3 <= 126.5\nsquared_error = 0.5\nsamples = 3\nvalue = 512.0'),
#  Text(0.2008974358974359, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.20294871794871794, 0.225, 'B/B Score.1 <= 129.0\nsquared_error = 0.222\nsamples = 2\nvalue = 512.333'),
#  Text(0.20192307692307693, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.20397435897435898, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.19833333333333333, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.19935897435897437, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 509.0'),
#  Text(0.20448717948717948, 0.525, 'B/B Score.3 <= 128.167\nsquared_error = 1.778\nsamples = 6\nvalue = 513.667'),
#  Text(0.20243589743589743, 0.475, 'P/S Score.2 <= 126.5\nsquared_error = 0.24\nsamples = 3\nvalue = 512.6'),
#  Text(0.20141025641025642, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.20346153846153847, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.20653846153846153, 0.475, 'B/B Score.4 <= 129.5\nsquared_error = 0.5\nsamples = 3\nvalue = 515.0'),
#  Text(0.20551282051282052, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.20756410256410257, 0.425, 'CARS Score.4 <= 126.833\nsquared_error = 0.222\nsamples = 2\nvalue = 515.333'),
#  Text(0.20653846153846153, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.20858974358974358, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.21064102564102563, 0.575, 'B/B Score.4 <= 129.0\nsquared_error = 8.5\nsamples = 4\nvalue = 516.0'),
#  Text(0.20961538461538462, 0.525, 'C/P Score.4 <= 127.167\nsquared_error = 0.222\nsamples = 3\nvalue = 517.667'),
#  Text(0.20858974358974358, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.21064102564102563, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 518.0'),
#  Text(0.21166666666666667, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.21371794871794872, 0.625, 'C/P Score.2 <= 128.167\nsquared_error = 0.244\nsamples = 28\nvalue = 509.574'),
#  Text(0.21269230769230768, 0.575, 'squared_error = 0.0\nsamples = 13\nvalue = 509.0'),
#  Text(0.21474358974358973, 0.575, 'squared_error = 0.0\nsamples = 15\nvalue = 510.0'),
#  Text(0.23448717948717948, 0.725, 'B/B Score.3 <= 128.167\nsquared_error = 4.706\nsamples = 113\nvalue = 513.08'),
#  Text(0.22371794871794873, 0.675, 'C/P Score.1 <= 127.167\nsquared_error = 2.541\nsamples = 63\nvalue = 512.072'),
#  Text(0.21884615384615386, 0.625, 'C/P Score.1 <= 126.5\nsquared_error = 2.992\nsamples = 6\nvalue = 509.091'),
#  Text(0.2167948717948718, 0.575, 'P/S Score.4 <= 126.5\nsquared_error = 1.0\nsamples = 4\nvalue = 510.0'),
#  Text(0.21576923076923077, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.21782051282051282, 0.525, 'squared_error = 0.0\nsamples = 3\nvalue = 511.0'),
#  Text(0.2208974358974359, 0.575, 'CARS Score.1 <= 127.167\nsquared_error = 0.222\nsamples = 2\nvalue = 506.667'),
#  Text(0.21987179487179487, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.22192307692307692, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.2285897435897436, 0.625, 'C/P Score.1 <= 129.167\nsquared_error = 1.201\nsamples = 57\nvalue = 512.453'),
#  Text(0.225, 0.575, 'CARS Score.1 <= 127.333\nsquared_error = 0.464\nsamples = 44\nvalue = 512.076'),
#  Text(0.22397435897435897, 0.525, 'B/B Score.3 <= 126.833\nsquared_error = 0.335\nsamples = 36\nvalue = 511.87'),
#  Text(0.22294871794871796, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.225, 0.475, 'Days Before Exam.4 <= 32.5\nsquared_error = 0.183\nsamples = 35\nvalue = 511.925'),
#  Text(0.22397435897435897, 0.425, 'Days Before Exam.3 <= 5.0\nsquared_error = 0.039\nsamples = 34\nvalue = 512.0'),
#  Text(0.22294871794871796, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.225, 0.375, 'CARS Score.2 <= 125.5\nsquared_error = 0.02\nsamples = 33\nvalue = 511.98'),
#  Text(0.22397435897435897, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.22602564102564102, 0.325, 'squared_error = 0.0\nsamples = 32\nvalue = 512.0'),
#  Text(0.22602564102564102, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.22602564102564102, 0.525, 'squared_error = 0.0\nsamples = 8\nvalue = 513.0'),
#  Text(0.2321794871794872, 0.575, 'B/B Score.1 <= 128.833\nsquared_error = 1.61\nsamples = 13\nvalue = 513.7'),
#  Text(0.23115384615384615, 0.525, 'CARS Score.4 <= 128.333\nsquared_error = 0.862\nsamples = 9\nvalue = 514.267'),
#  Text(0.2291025641025641, 0.475, 'Days Before Exam.1 <= 6.667\nsquared_error = 0.331\nsamples = 6\nvalue = 513.818'),
#  Text(0.22807692307692307, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.23012820512820512, 0.425, 'squared_error = 0.0\nsamples = 5\nvalue = 514.0'),
#  Text(0.2332051282051282, 0.475, 'B/B Score.3 <= 127.667\nsquared_error = 0.25\nsamples = 3\nvalue = 515.5'),
#  Text(0.2321794871794872, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 516.0'),
#  Text(0.23423076923076924, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.2332051282051282, 0.525, 'squared_error = 0.0\nsamples = 4\nvalue = 512.0'),
#  Text(0.24525641025641026, 0.675, 'CARS Score.4 <= 126.167\nsquared_error = 4.539\nsamples = 50\nvalue = 514.351'),
#  Text(0.23935897435897435, 0.625, 'Days Before Exam.1 <= 11.167\nsquared_error = 3.422\nsamples = 12\nvalue = 511.667'),
#  Text(0.23833333333333334, 0.575, 'C/P Score.1 <= 127.167\nsquared_error = 1.209\nsamples = 11\nvalue = 512.071'),
#  Text(0.2362820512820513, 0.525, 'P/S Score.1 <= 129.333\nsquared_error = 0.188\nsamples = 3\nvalue = 510.75'),
#  Text(0.23525641025641025, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 511.0'),
#  Text(0.2373076923076923, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.2403846153846154, 0.525, 'CARS Score.1 <= 126.833\nsquared_error = 0.64\nsamples = 8\nvalue = 512.6'),
#  Text(0.23935897435897435, 0.475, 'squared_error = 0.0\nsamples = 4\nvalue = 512.0'),
#  Text(0.2414102564102564, 0.475, 'Days Before Exam.3 <= 34.5\nsquared_error = 0.25\nsamples = 4\nvalue = 513.5'),
#  Text(0.2403846153846154, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.24243589743589744, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.2403846153846154, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.25115384615384617, 0.625, 'P/S Score.1 <= 129.167\nsquared_error = 2.645\nsamples = 38\nvalue = 515.0'),
#  Text(0.2485897435897436, 0.575, 'P/S Score.1 <= 128.5\nsquared_error = 1.37\nsamples = 31\nvalue = 514.52'),
#  Text(0.24653846153846154, 0.525, 'Days Before Exam.1 <= 7.167\nsquared_error = 0.734\nsamples = 9\nvalue = 513.375'),
#  Text(0.2455128205128205, 0.475, 'CARS Score.3 <= 126.667\nsquared_error = 0.222\nsamples = 4\nvalue = 512.333'),
#  Text(0.2444871794871795, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 512.0'),
#  Text(0.24653846153846154, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.24756410256410255, 0.475, 'squared_error = 0.0\nsamples = 5\nvalue = 514.0'),
#  Text(0.25064102564102564, 0.525, 'CARS Score.3 <= 126.167\nsquared_error = 0.761\nsamples = 22\nvalue = 515.059'),
#  Text(0.24961538461538463, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.25166666666666665, 0.475, 'B/B Score.4 <= 127.167\nsquared_error = 0.299\nsamples = 21\nvalue = 514.939'),
#  Text(0.25064102564102564, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.2526923076923077, 0.425, 'P/S Score.2 <= 127.333\nsquared_error = 0.03\nsamples = 20\nvalue = 515.031'),
#  Text(0.25166666666666665, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.2537179487179487, 0.375, 'squared_error = 0.0\nsamples = 19\nvalue = 515.0'),
#  Text(0.2537179487179487, 0.575, 'P/S Score.4 <= 127.0\nsquared_error = 3.0\nsamples = 7\nvalue = 517.0'),
#  Text(0.2526923076923077, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.25474358974358974, 0.525, 'P/S Score.3 <= 126.833\nsquared_error = 0.793\nsamples = 6\nvalue = 517.455'),
#  Text(0.2537179487179487, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.25576923076923075, 0.475, 'C/P Score.4 <= 130.5\nsquared_error = 0.16\nsamples = 5\nvalue = 517.2'),
#  Text(0.25474358974358974, 0.425, 'squared_error = 0.0\nsamples = 4\nvalue = 517.0'),
#  Text(0.2567948717948718, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.29633814102564104, 0.775, 'B/B Score.2 <= 128.5\nsquared_error = 8.813\nsamples = 228\nvalue = 515.337'),
#  Text(0.2685897435897436, 0.725, 'CARS Score.1 <= 126.833\nsquared_error = 4.533\nsamples = 72\nvalue = 513.066'),
#  Text(0.26346153846153847, 0.675, 'CARS Score.2 <= 129.333\nsquared_error = 1.781\nsamples = 52\nvalue = 512.054'),
#  Text(0.25987179487179485, 0.625, 'CARS Score.4 <= 123.5\nsquared_error = 1.142\nsamples = 49\nvalue = 511.887'),
#  Text(0.2578205128205128, 0.575, 'Days Before Exam.3 <= 10.0\nsquared_error = 0.222\nsamples = 2\nvalue = 508.333'),
#  Text(0.2567948717948718, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.25884615384615384, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.2619230769230769, 0.575, 'Days Before Exam.2 <= 26.5\nsquared_error = 0.601\nsamples = 47\nvalue = 512.044'),
#  Text(0.2608974358974359, 0.525, 'Days Before Exam.4 <= 126.0\nsquared_error = 0.346\nsamples = 46\nvalue = 511.955'),
#  Text(0.25987179487179485, 0.475, 'B/B Score.2 <= 126.5\nsquared_error = 0.215\nsamples = 45\nvalue = 512.0'),
#  Text(0.25884615384615384, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.2608974358974359, 0.425, 'C/P Score.1 <= 127.0\nsquared_error = 0.076\nsamples = 44\nvalue = 512.047'),
#  Text(0.25987179487179485, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.2619230769230769, 0.375, 'P/S Score.1 <= 129.5\nsquared_error = 0.016\nsamples = 43\nvalue = 512.016'),
#  Text(0.2608974358974359, 0.325, 'squared_error = 0.0\nsamples = 42\nvalue = 512.0'),
#  Text(0.26294871794871794, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.2619230769230769, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.26294871794871794, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.26705128205128204, 0.625, 'C/P Score.1 <= 128.333\nsquared_error = 0.667\nsamples = 3\nvalue = 516.0'),
#  Text(0.266025641025641, 0.575, 'B/B Score.3 <= 128.833\nsquared_error = 0.25\nsamples = 2\nvalue = 516.5'),
#  Text(0.265, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.26705128205128204, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.2680769230769231, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.27371794871794874, 0.675, 'P/S Score.1 <= 128.5\nsquared_error = 3.054\nsamples = 20\nvalue = 515.406'),
#  Text(0.27115384615384613, 0.625, 'P/S Score.1 <= 128.167\nsquared_error = 2.143\nsamples = 10\nvalue = 514.0'),
#  Text(0.2701282051282051, 0.575, 'C/P Score.1 <= 127.667\nsquared_error = 0.75\nsamples = 9\nvalue = 514.5'),
#  Text(0.2691025641025641, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.27115384615384613, 0.525, 'squared_error = 0.0\nsamples = 8\nvalue = 514.0'),
#  Text(0.2721794871794872, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.2762820512820513, 0.625, 'Days Before Exam.1 <= 4.333\nsquared_error = 1.028\nsamples = 10\nvalue = 516.5'),
#  Text(0.2742307692307692, 0.575, 'C/P Score.1 <= 129.5\nsquared_error = 0.234\nsamples = 3\nvalue = 517.375'),
# ...
#  Text(0.48115384615384615, 0.475, 'CARS Score.3 <= 128.5\nsquared_error = 0.188\nsamples = 4\nvalue = 517.25'),
#  Text(0.48012820512820514, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.48217948717948717, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 517.0'),
#  Text(0.48525641025641025, 0.475, 'Days Before Exam.4 <= 19.5\nsquared_error = 0.24\nsamples = 4\nvalue = 515.6'),
#  Text(0.48423076923076924, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.48628205128205126, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 516.0'),
#  Text(0.48628205128205126, 0.575, 'Days Before Exam.3 <= 10.5\nsquared_error = 0.96\nsamples = 3\nvalue = 520.2'),
#  Text(0.48525641025641025, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.48730769230769233, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.49243589743589744, 0.625, 'P/S Score.4 <= 128.5\nsquared_error = 1.076\nsamples = 8\nvalue = 520.583'),
#  Text(0.49038461538461536, 0.575, 'Days Before Exam.2 <= 11.167\nsquared_error = 0.64\nsamples = 4\nvalue = 519.6'),
#  Text(0.48935897435897435, 0.525, 'P/S Score.3 <= 129.5\nsquared_error = 0.25\nsamples = 2\nvalue = 520.5'),
#  Text(0.48833333333333334, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.49038461538461536, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.49141025641025643, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 519.0'),
#  Text(0.49448717948717946, 0.575, 'CARS Score.1 <= 130.667\nsquared_error = 0.204\nsamples = 4\nvalue = 521.286'),
#  Text(0.49346153846153845, 0.525, 'squared_error = 0.0\nsamples = 3\nvalue = 521.0'),
#  Text(0.49551282051282053, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.5523758012820513, 0.825, 'CARS Score.1 <= 128.833\nsquared_error = 6.251\nsamples = 426\nvalue = 517.621'),
#  Text(0.5230769230769231, 0.775, 'P/S Score.1 <= 129.494\nsquared_error = 3.677\nsamples = 212\nvalue = 516.342'),
#  Text(0.5137179487179487, 0.725, 'CARS Score.4 <= 131.5\nsquared_error = 2.452\nsamples = 107\nvalue = 515.357'),
#  Text(0.5083333333333333, 0.675, 'C/P Score.1 <= 128.333\nsquared_error = 1.676\nsamples = 105\nvalue = 515.459'),
#  Text(0.5006410256410256, 0.625, 'CARS Score.4 <= 127.833\nsquared_error = 6.654\nsamples = 10\nvalue = 516.889'),
#  Text(0.4985897435897436, 0.575, 'CARS Score.4 <= 126.333\nsquared_error = 2.75\nsamples = 3\nvalue = 513.5'),
#  Text(0.49756410256410255, 0.525, 'Days Before Exam.2 <= 73.5\nsquared_error = 1.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.49653846153846154, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.4985897435897436, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.49961538461538463, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.5026923076923077, 0.575, 'P/S Score.3 <= 127.0\nsquared_error = 3.551\nsamples = 7\nvalue = 517.857'),
#  Text(0.5016666666666667, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.5037179487179487, 0.525, 'P/S Score.4 <= 128.167\nsquared_error = 0.698\nsamples = 6\nvalue = 517.385'),
#  Text(0.5016666666666667, 0.475, 'P/S Score.2 <= 128.0\nsquared_error = 0.25\nsamples = 2\nvalue = 518.5'),
#  Text(0.5006410256410256, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5026923076923077, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5057692307692307, 0.475, 'CARS Score.3 <= 129.5\nsquared_error = 0.099\nsamples = 4\nvalue = 516.889'),
#  Text(0.5047435897435898, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 517.0'),
#  Text(0.5067948717948718, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5160256410256411, 0.625, 'B/B Score.1 <= 129.667\nsquared_error = 0.815\nsamples = 95\nvalue = 515.29'),
#  Text(0.5119230769230769, 0.575, 'Days Before Exam.1 <= 3.5\nsquared_error = 0.61\nsamples = 92\nvalue = 515.229'),
#  Text(0.5108974358974359, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.512948717948718, 0.525, 'B/B Score.1 <= 128.333\nsquared_error = 0.372\nsamples = 91\nvalue = 515.286'),
#  Text(0.5098717948717949, 0.475, 'Days Before Exam.1 <= 11.667\nsquared_error = 0.186\nsamples = 52\nvalue = 514.962'),
#  Text(0.5088461538461538, 0.425, 'B/B Score.1 <= 127.167\nsquared_error = 0.076\nsamples = 51\nvalue = 515.0'),
#  Text(0.5078205128205128, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.5098717948717949, 0.375, 'C/P Score.1 <= 129.167\nsquared_error = 0.025\nsamples = 50\nvalue = 515.026'),
#  Text(0.5088461538461538, 0.325, 'squared_error = 0.0\nsamples = 48\nvalue = 515.0'),
#  Text(0.5108974358974359, 0.325, 'C/P Score.3 <= 128.667\nsquared_error = 0.222\nsamples = 2\nvalue = 515.667'),
#  Text(0.5098717948717949, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.5119230769230769, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5108974358974359, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.5160256410256411, 0.475, 'CARS Score.1 <= 128.536\nsquared_error = 0.319\nsamples = 39\nvalue = 515.673'),
#  Text(0.515, 0.425, 'CARS Score.3 <= 124.5\nsquared_error = 0.197\nsamples = 38\nvalue = 515.751'),
#  Text(0.513974358974359, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5160256410256411, 0.375, 'CARS Score.2 <= 129.167\nsquared_error = 0.101\nsamples = 37\nvalue = 515.808'),
#  Text(0.515, 0.325, 'CARS Score.1 <= 128.203\nsquared_error = 0.03\nsamples = 36\nvalue = 515.747'),
#  Text(0.513974358974359, 0.275, 'squared_error = 0.0\nsamples = 13\nvalue = 516.0'),
#  Text(0.5160256410256411, 0.275, 'squared_error = 0.0\nsamples = 23\nvalue = 515.627'),
#  Text(0.517051282051282, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.517051282051282, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5201282051282051, 0.575, 'B/B Score.3 <= 131.0\nsquared_error = 1.556\nsamples = 3\nvalue = 518.333'),
#  Text(0.5191025641025641, 0.525, 'B/B Score.2 <= 130.5\nsquared_error = 0.25\nsamples = 2\nvalue = 517.5'),
#  Text(0.5180769230769231, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5201282051282051, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.5211538461538462, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5191025641025641, 0.675, 'Days Before Exam.2 <= 17.5\nsquared_error = 16.0\nsamples = 2\nvalue = 511.0'),
#  Text(0.5180769230769231, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.5201282051282051, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.5324358974358975, 0.725, 'CARS Score.3 <= 123.5\nsquared_error = 2.796\nsamples = 105\nvalue = 517.419'),
#  Text(0.5314102564102564, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.5334615384615384, 0.675, 'P/S Score.1 <= 131.5\nsquared_error = 1.831\nsamples = 104\nvalue = 517.498'),
#  Text(0.5293589743589744, 0.625, 'Days Before Exam.1 <= 14.5\nsquared_error = 1.413\nsamples = 101\nvalue = 517.39'),
#  Text(0.5262820512820513, 0.575, 'Days Before Exam.1 <= 7.5\nsquared_error = 1.796\nsamples = 55\nvalue = 516.881'),
#  Text(0.5232051282051282, 0.525, 'Days Before Exam.1 <= 3.5\nsquared_error = 1.136\nsamples = 51\nvalue = 517.111'),
#  Text(0.5221794871794871, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5242307692307693, 0.475, 'C/P Score.4 <= 125.5\nsquared_error = 0.625\nsamples = 50\nvalue = 516.921'),
#  Text(0.5232051282051282, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5252564102564102, 0.425, 'Days Before Exam.3 <= 36.0\nsquared_error = 0.379\nsamples = 49\nvalue = 516.838'),
#  Text(0.5242307692307693, 0.375, 'B/B Score.1 <= 128.167\nsquared_error = 0.18\nsamples = 48\nvalue = 516.89'),
#  Text(0.5232051282051282, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5252564102564102, 0.325, 'B/B Score.1 <= 129.667\nsquared_error = 0.065\nsamples = 47\nvalue = 516.931'),
#  Text(0.5242307692307693, 0.275, 'squared_error = 0.0\nsamples = 44\nvalue = 517.0'),
#  Text(0.5262820512820513, 0.275, 'squared_error = 0.0\nsamples = 3\nvalue = 516.0'),
#  Text(0.5262820512820513, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.5293589743589744, 0.525, 'P/S Score.2 <= 130.5\nsquared_error = 0.358\nsamples = 4\nvalue = 513.778'),
#  Text(0.5283333333333333, 0.475, 'C/P Score.4 <= 129.5\nsquared_error = 0.083\nsamples = 2\nvalue = 514.167'),
#  Text(0.5273076923076923, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.667'),
#  Text(0.5293589743589744, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5303846153846153, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.5324358974358975, 0.575, 'P/S Score.1 <= 130.0\nsquared_error = 0.118\nsamples = 46\nvalue = 518.061'),
#  Text(0.5314102564102564, 0.525, 'squared_error = 0.0\nsamples = 45\nvalue = 518.0'),
#  Text(0.5334615384615384, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5375641025641026, 0.625, 'B/B Score.2 <= 131.0\nsquared_error = 3.36\nsamples = 3\nvalue = 520.8'),
#  Text(0.5365384615384615, 0.575, 'C/P Score.1 <= 128.0\nsquared_error = 0.222\nsamples = 2\nvalue = 519.333'),
#  Text(0.5355128205128206, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5375641025641026, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5385897435897435, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.5816746794871794, 0.775, 'P/S Score.1 <= 130.167\nsquared_error = 5.529\nsamples = 214\nvalue = 518.912'),
#  Text(0.5678365384615385, 0.725, 'Days Before Exam.1 <= 8.167\nsquared_error = 4.842\nsamples = 164\nvalue = 518.355'),
#  Text(0.5560576923076923, 0.675, 'Days Before Exam.1 <= 3.5\nsquared_error = 4.947\nsamples = 136\nvalue = 518.642'),
#  Text(0.5432051282051282, 0.625, 'B/B Score.3 <= 130.5\nsquared_error = 16.155\nsamples = 15\nvalue = 516.053'),
#  Text(0.5421794871794872, 0.575, 'B/B Score.2 <= 128.5\nsquared_error = 5.472\nsamples = 14\nvalue = 516.833'),
#  Text(0.5396153846153846, 0.525, 'CARS Score.4 <= 129.5\nsquared_error = 0.688\nsamples = 4\nvalue = 520.25'),
#  Text(0.5385897435897435, 0.475, 'P/S Score.2 <= 129.5\nsquared_error = 0.25\nsamples = 2\nvalue = 519.5'),
#  Text(0.5375641025641026, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5396153846153846, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5406410256410257, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.5447435897435897, 0.525, 'P/S Score.3 <= 128.833\nsquared_error = 2.551\nsamples = 10\nvalue = 515.857'),
#  Text(0.5426923076923077, 0.475, 'C/P Score.3 <= 128.5\nsquared_error = 1.058\nsamples = 8\nvalue = 515.182'),
#  Text(0.5416666666666666, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5437179487179488, 0.425, 'Days Before Exam.4 <= 29.5\nsquared_error = 0.29\nsamples = 7\nvalue = 514.9'),
#  Text(0.5426923076923077, 0.375, 'P/S Score.2 <= 130.0\nsquared_error = 0.109\nsamples = 5\nvalue = 515.125'),
#  Text(0.5416666666666666, 0.325, 'squared_error = 0.0\nsamples = 4\nvalue = 515.0'),
#  Text(0.5437179487179488, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5447435897435897, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.5467948717948717, 0.475, 'P/S Score.2 <= 129.5\nsquared_error = 0.222\nsamples = 2\nvalue = 518.333'),
#  Text(0.5457692307692308, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5478205128205128, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5442307692307692, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 502.0'),
#  Text(0.5689102564102564, 0.625, 'B/B Score.1 <= 130.5\nsquared_error = 3.119\nsamples = 121\nvalue = 518.896'),
#  Text(0.5633333333333334, 0.575, 'B/B Score.2 <= 129.167\nsquared_error = 2.189\nsamples = 118\nvalue = 518.724'),
#  Text(0.5552564102564103, 0.525, 'P/S Score.1 <= 129.5\nsquared_error = 5.634\nsamples = 20\nvalue = 517.821'),
#  Text(0.5524358974358974, 0.475, 'P/S Score.3 <= 126.5\nsquared_error = 7.384\nsamples = 11\nvalue = 516.913'),
#  Text(0.5498717948717948, 0.425, 'B/B Score.2 <= 128.0\nsquared_error = 3.556\nsamples = 2\nvalue = 521.333'),
#  Text(0.5488461538461539, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5508974358974359, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.555, 0.425, 'CARS Score.2 <= 128.5\nsquared_error = 4.588\nsamples = 9\nvalue = 516.25'),
#  Text(0.5529487179487179, 0.375, 'Days Before Exam.1 <= 4.5\nsquared_error = 0.765\nsamples = 3\nvalue = 514.889'),
#  Text(0.551923076923077, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.553974358974359, 0.325, 'CARS Score.2 <= 127.5\nsquared_error = 0.234\nsamples = 2\nvalue = 514.625'),
#  Text(0.5529487179487179, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.555, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5570512820512821, 0.375, 'C/P Score.4 <= 127.0\nsquared_error = 4.959\nsamples = 6\nvalue = 517.364'),
#  Text(0.556025641025641, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.558076923076923, 0.325, 'Days Before Exam.1 <= 6.0\nsquared_error = 2.29\nsamples = 5\nvalue = 517.9'),
#  Text(0.5570512820512821, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.5591025641025641, 0.275, 'Days Before Exam.3 <= 18.5\nsquared_error = 0.234\nsamples = 4\nvalue = 518.625'),
#  Text(0.558076923076923, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5601282051282052, 0.225, 'squared_error = 0.0\nsamples = 3\nvalue = 519.0'),
#  Text(0.558076923076923, 0.475, 'B/B Score.1 <= 129.333\nsquared_error = 0.234\nsamples = 9\nvalue = 519.125'),
#  Text(0.5570512820512821, 0.425, 'squared_error = 0.0\nsamples = 8\nvalue = 519.0'),
#  Text(0.5591025641025641, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.5714102564102564, 0.525, 'C/P Score.1 <= 127.833\nsquared_error = 0.992\nsamples = 98\nvalue = 518.966'),
#  Text(0.5703846153846154, 0.475, 'squared_error = 0.0\nsamples = 18\nvalue = 518.0'),
#  Text(0.5724358974358974, 0.475, 'B/B Score.1 <= 129.5\nsquared_error = 0.954\nsamples = 80\nvalue = 519.195'),
#  Text(0.5683333333333334, 0.425, 'P/S Score.2 <= 130.5\nsquared_error = 0.759\nsamples = 76\nvalue = 519.081'),
#  Text(0.5642307692307692, 0.375, 'CARS Score.1 <= 130.5\nsquared_error = 0.356\nsamples = 69\nvalue = 518.94'),
#  Text(0.5621794871794872, 0.325, 'CARS Score.1 <= 129.667\nsquared_error = 0.01\nsamples = 66\nvalue = 519.01'),
#  Text(0.5611538461538461, 0.275, 'squared_error = 0.0\nsamples = 65\nvalue = 519.0'),
#  Text(0.5632051282051282, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5662820512820513, 0.325, 'P/S Score.3 <= 126.667\nsquared_error = 6.222\nsamples = 3\nvalue = 516.667'),
#  Text(0.5652564102564103, 0.275, 'P/S Score.2 <= 128.667\nsquared_error = 1.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.5642307692307692, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5662820512820513, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5673076923076923, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5724358974358974, 0.375, 'CARS Score.1 <= 129.667\nsquared_error = 2.595\nsamples = 7\nvalue = 520.364'),
#  Text(0.5703846153846154, 0.325, 'B/B Score.2 <= 130.5\nsquared_error = 0.204\nsamples = 4\nvalue = 519.286'),
#  Text(0.5693589743589743, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5714102564102564, 0.275, 'squared_error = 0.0\nsamples = 3\nvalue = 519.0'),
#  Text(0.5744871794871795, 0.325, 'B/B Score.3 <= 129.5\nsquared_error = 1.188\nsamples = 3\nvalue = 522.25'),
#  Text(0.5734615384615385, 0.275, 'Days Before Exam.1 <= 6.0\nsquared_error = 0.222\nsamples = 2\nvalue = 521.667'),
#  Text(0.5724358974358974, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  ...]

# %%
#conda uninstall python-graphviz
#conda uninstall graphviz
#pip install dtreeviz             # install dtreeviz for sklearn
#pip install dtreeviz[xgboost]    # install XGBoost related dependency
#pip install dtreeviz[pyspark]    # install pyspark related dependency
#pip install dtreeviz[lightgbm]   # install LightGBM related dependency
#pip install graphviz

# %%
from dtreeviz.trees import dtreeviz

viz = dtreeviz(rf.estimators_[0], X_train, y_train,
               target_name = "Real MCAT Score",
               feature_names = features,
               title = "Decision Tree for MCAT Scores")

viz.save("MCAT_decision_tree.svg")            
viz.view()

# %% [markdown]
# ## Compare All ML Methods Using Validation Sets

# %%
# results stores the dictionary returned by the cross validation
# results thus becomes a list of dictionaries
# nmse stores the *mean* of all the neg_mean_squared_error's from each of k runs
results = []
nmse = []

# Linear Regression without Dimensionality Reduction
model_validation(X_train, y_train, results, nmse)
# Linear Regression with Dimensionality Reduction
for n in range(X_train.shape[1]):
    pca = PCA(n_components=n+1)
    X_train_reduced = pca.fit_transform(X_train)
    model_validation(X_train_reduced, y_train, results, nmse)
# Display the results
for i in range(0, len(nmse), 1):
    if i == 0:
        print("neg mean squared error of linear regression: ", nmse[i])
    else:
        print("neg mean squared error of linear regression with ", i, " dimensions is ", nmse[i])
# Out:
# neg mean squared error of linear regression:  -7.642995892489457
# neg mean squared error of linear regression with  1  dimensions is  -47.03356814929124
# neg mean squared error of linear regression with  2  dimensions is  -47.0170472305962
# neg mean squared error of linear regression with  3  dimensions is  -46.84055790991218
# neg mean squared error of linear regression with  4  dimensions is  -46.84885926355991
# neg mean squared error of linear regression with  5  dimensions is  -8.162376224324985
# neg mean squared error of linear regression with  6  dimensions is  -8.132838108972006
# neg mean squared error of linear regression with  7  dimensions is  -7.956855811024855
# neg mean squared error of linear regression with  8  dimensions is  -7.8988399462496455
# neg mean squared error of linear regression with  9  dimensions is  -7.89811057571886
# neg mean squared error of linear regression with  10  dimensions is  -7.88833468165986
# neg mean squared error of linear regression with  11  dimensions is  -7.881827556073726
# neg mean squared error of linear regression with  12  dimensions is  -7.815764149654308
# neg mean squared error of linear regression with  13  dimensions is  -7.750021620022222
# neg mean squared error of linear regression with  14  dimensions is  -7.7170761105657375
# neg mean squared error of linear regression with  15  dimensions is  -7.67979931586127
# neg mean squared error of linear regression with  16  dimensions is  -7.6737553314956894
# neg mean squared error of linear regression with  17  dimensions is  -7.676134775866464
# neg mean squared error of linear regression with  18  dimensions is  -7.6782543648190344
# neg mean squared error of linear regression with  19  dimensions is  -7.642442408752308
# neg mean squared error of linear regression with  20  dimensions is  -7.64299589248944

# %% [markdown]
# # Evaluate the Metrics of the Best Model

# %%
#The choosed model is PCA with 10 components
pca = PCA(n_components=10)
X_train_reduced = pca.fit_transform(X_train)

# train the model on all the training data
lin_reg1 = LinearRegression()
lin_reg1 = lin_reg1.fit(X_train_reduced, y_train)

# transform the testing data to the same space as the training data
X_test_reduced = pca.transform(X_test)

# evaluate the model's accuracy using the test data
R2 = lin_reg1.score(X_test_reduced, y_test)
print(f"The coefficient of determination: {R2:.2f}")

# use loss function on prediction vs. test
y_pred = lin_reg1.predict(X_test_reduced)
mse = mean_squared_error(y_test, y_pred)
print("neg mean squared error of the final ML model: ", -mse)
# Out:
# The coefficient of determination: 0.84
# neg mean squared error of the final ML model:  -7.469869882429596

# %%
y_pred_rf = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred_rf)
print("neg mean squared error of the final ML model: ", -mse)
# Out:
# neg mean squared error of the final ML model:  -4.792460899661642

# %% [markdown]
# # Data visualisation

# %%
#Display what pca 1 is
plt.figure()

print(X.shape)
D,E = np.linalg.eig(np.matmul(X.T,X))
#print(D)
#print(D.shape)
#E = E.reshape()
z = list(scores.columns[1:])#np.arange(1,21)
#print(z)

fig, ax = plt.subplots(figsize= (8,4))
# We see that the highest eigenvalue is D[7] so row 7 of E is 
ax.bar(z, E[:,7])#, label=bar_labels, color=bar_colors)

ax.set_ylabel('PCA 1 dimension')
ax.set_title('PCA 1 in fonction of the features')
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right',fontsize=8)
#ax.legend(title='Fruit color')

plt.show()

#plt.plot(z,E[0,:])

# %%
plt.figure(figsize=(10, 8))
# convert the labels to numbers, each will be assigned a separate color based on the cmap specified
colors = [int(x) for x in y_train]
sc = plt.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], c=colors)#,s=1 cmap='tab10')
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend(*sc.legend_elements(), title='digit')
plt.show()

# %%
#3D plotting
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], X_train_reduced[:,2], c=colors)
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('PCA 3')
plt.legend(*sc.legend_elements(), title='digit',loc="upper center")
plt.show()

# %%
#3D plotting
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
ax.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], y_train)#, c=colors)
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel("Final score")
#plt.legend(*sc.legend_elements(), title='digit',loc="upper center")
plt.title("Final scores at exam of the training set in function of PCA1 and PCA2 parameters")
plt.show()

# %%
plt.figure(figsize=(6, 6))
# convert the labels to numbers, each will be assigned a separate color based on the cmap specified
colors = [int(x) for x in y_train]
sc = plt.scatter(X_train_reduced[:, 0],y_train)#, c=colors)#,s=1 cmap='tab10')
plt.xlabel("PCA1")
plt.ylabel("Final score")
#plt.legend(*sc.legend_elements(), title='digit')
plt.title("Final scores at exam of the training set in function of PCA1 parameter")
plt.show()
