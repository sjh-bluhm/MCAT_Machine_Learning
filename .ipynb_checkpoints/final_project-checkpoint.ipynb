# %%
#import necessary modules
#Python >= 3.5
import sys
assert sys.version_info >= (3, 5)

#Scikit-Learn >= 0.20
import sklearn as sk
assert sk.__version__ >= "0.20"
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

#numpy for calculations
import numpy as np
import os

#matplotlib for figures
import matplotlib as mpl
import matplotlib.pyplot as plt
#a magic function that allows inline plotting so figures are rendered in this notebook
# %matplotlib inline

#pandas for ...
import pandas as pd
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Setup and Feature Statistics

# %%
# load data from the cv file using pandas
scores = pd.read_csv("Complete MCAT Data.csv", header = 1)

# rename some columns for consistency
scores.rename(columns = {'Days Before Exam':'Days Before Exam.1', 'Days Before Exam.1':'Days Before Exam.2', 'Days Before Exam.2':'Days Before Exam.3', 'Days Before Exam.3':'Days Before Exam.4'}, inplace = True)

# preview first five lines
scores.head()
# Out:
#            Timestamp  Exam Date  Real Score  C/P Score  CARS Score  B/B Score  \
# 0  2/19/2020 2:17:07  1/18/2020       513.0      128.0       128.0      129.0
# 1  2/19/2020 2:32:30  1/17/2020       495.0      122.0       127.0      122.0
# 2  2/19/2020 2:32:57  1/18/2020       522.0      130.0       129.0      131.0
# 3  2/19/2020 2:37:04  1/17/2020       515.0      128.0       129.0      128.0
# 4  2/19/2020 2:37:05  1/17/2020       522.0      131.0       131.0      130.0
#
#    P/S Score  Days Before Exam.1  Total Score  C/P Score.1  ...  C/P Score.3  \
# 0      128.0                 NaN          NaN          NaN  ...        128.0
# 1      124.0                 NaN          NaN          NaN  ...          NaN
# 2      132.0                 5.0        519.0        129.0  ...          NaN
# 3      130.0                 7.0        515.0        129.0  ...        127.0
# 4      130.0                 8.0        519.0        131.0  ...        130.0
#
#    CARS Score.3  B/B Score.3  P/S Score.3  Days Before Exam.4  Total Score.3  \
# 0         128.0        128.0        126.0                  16            506
# 1           NaN          NaN          NaN                 NaN            NaN
# 2           NaN          NaN          NaN                 512            NaN
# 3         127.0        129.0        127.0                  28            506
# 4         129.0        130.0        131.0                  15            519
#
#    C/P Score.4  CARS Score.4  B/B Score.4 P/S Score.4
# 0          127           127          125         127
# 1          NaN           NaN          NaN         NaN
# 2          NaN           NaN          NaN         NaN
# 3          127           125          127         127
# 4          129           130          129         131
#
# [5 rows x 31 columns]

# %%
# drop irrelevant columns
scores.drop(columns=['Timestamp', 'Exam Date', 'C/P Score', 'CARS Score', 'B/B Score', 'P/S Score', 'Total Score', 'Total Score.1', 'Total Score.2', 'Total Score.3'], inplace = True)

# sanity check: take a look at the data
print('Scores data shape:', scores.shape)

# look at distribution of scores
scores['Real Score'].value_counts()

# gives count, mean, standard deviation, min, max, and percentiles (including median)
scores.describe(percentiles = [0.25, 0.5, 0.75], include = 'all')
# Out:
# Scores data shape: (4996, 21)
#          Real Score  Days Before Exam.1  C/P Score.1  CARS Score.1  \
# count   4948.000000         1733.000000  1502.000000   1498.000000
# unique          NaN                 NaN          NaN           NaN
# top             NaN                 NaN          NaN           NaN
# freq            NaN                 NaN          NaN           NaN
# mean     515.914511            8.417773   129.312250    128.403872
# std       23.805011           16.390119     1.996091      2.083215
# min      417.000000            0.000000   120.000000    120.000000
# 25%      512.000000            4.000000   128.000000    127.000000
# 50%      517.000000            6.000000   130.000000    129.000000
# 75%      520.000000            7.000000   131.000000    130.000000
# max     2115.000000          365.000000   132.000000    132.000000
#
#         B/B Score.1  P/S Score.1  Days Before Exam.2  C/P Score.2  \
# count   1496.000000  1496.000000         2567.000000  2330.000000
# unique          NaN          NaN                 NaN          NaN
# top             NaN          NaN                 NaN          NaN
# freq            NaN          NaN                 NaN          NaN
# mean     129.037433   129.328877           21.421504   129.054506
# std        1.835347     1.885376          365.928234     1.919827
# min      122.000000   122.000000        -8764.000000   121.000000
# 25%      128.000000   128.000000            6.000000   128.000000
# 50%      129.000000   130.000000            9.000000   129.000000
# 75%      130.000000   131.000000           14.000000   130.000000
# max      132.000000   132.000000        10227.000000   132.000000
#
#         CARS Score.2  B/B Score.2  ...  Days Before Exam.3  C/P Score.3  \
# count    2329.000000  2327.000000  ...                3303  3044.000000
# unique           NaN          NaN  ...                 166          NaN
# top              NaN          NaN  ...                  21          NaN
# freq             NaN          NaN  ...                 333          NaN
# mean      128.280807   129.329179  ...                 NaN   128.729632
# std         2.156899     1.804962  ...                 NaN     1.988670
# min       122.000000   120.000000  ...                 NaN   118.000000
# 25%       127.000000   128.000000  ...                 NaN   127.000000
# 50%       128.000000   130.000000  ...                 NaN   129.000000
# 75%       130.000000   131.000000  ...                 NaN   130.000000
# max       132.000000   132.000000  ...                 NaN   132.000000
#
#         CARS Score.3  B/B Score.3  P/S Score.3  Days Before Exam.4  \
# count    3043.000000  3042.000000  3042.000000                3340
# unique           NaN          NaN          NaN                 242
# top              NaN          NaN          NaN                  28
# freq             NaN          NaN          NaN                 269
# mean      128.400920   128.880342   127.856673                 NaN
# std         2.358199     1.905568     1.745526                 NaN
# min       118.000000   118.000000   118.000000                 NaN
# 25%       127.000000   128.000000   127.000000                 NaN
# 50%       129.000000   129.000000   128.000000                 NaN
# 75%       130.000000   130.000000   129.000000                 NaN
# max       132.000000   132.000000   132.000000                 NaN
#
#        C/P Score.4 CARS Score.4 B/B Score.4 P/S Score.4
# count         3544         3543        3541        3544
# unique          17           17          18          18
# top            130          128         130         129
# freq           676          799         796         812
# mean           NaN          NaN         NaN         NaN
# std            NaN          NaN         NaN         NaN
# min            NaN          NaN         NaN         NaN
# 25%            NaN          NaN         NaN         NaN
# 50%            NaN          NaN         NaN         NaN
# 75%            NaN          NaN         NaN         NaN
# max            NaN          NaN         NaN         NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# ## Visualize and Handle Missing Data

# %%
# pip install missingno
import missingno as msno

# visualize missing data with Missingno
msno.bar(scores)
msno.matrix(scores)

# see if there is a reason for missing data
msno.heatmap(scores)
msno.dendrogram(scores)
# Out:
# <AxesSubplot:>

# %%
# drop all rows with missing values
scores.dropna(axis = 0, inplace = True)

# convert all remaining data to integers
for col in scores.columns:
        scores[col] = scores[col].astype(int)

# %%
# print number of columns, column labels, column data types, memory usage, range index, and non-null number of cells in each column
scores.info()

# preview data
scores.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1240 entries, 3 to 4297
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Real Score          1240 non-null   int64
#  1   Days Before Exam.1  1240 non-null   int64
#  2   C/P Score.1         1240 non-null   int64
#  3   CARS Score.1        1240 non-null   int64
#  4   B/B Score.1         1240 non-null   int64
#  5   P/S Score.1         1240 non-null   int64
#  6   Days Before Exam.2  1240 non-null   int64
#  7   C/P Score.2         1240 non-null   int64
#  8   CARS Score.2        1240 non-null   int64
#  9   B/B Score.2         1240 non-null   int64
#  10  P/S Score.2         1240 non-null   int64
#  11  Days Before Exam.3  1240 non-null   int64
#  12  C/P Score.3         1240 non-null   int64
#  13  CARS Score.3        1240 non-null   int64
#  14  B/B Score.3         1240 non-null   int64
#  15  P/S Score.3         1240 non-null   int64
#  16  Days Before Exam.4  1240 non-null   int64
#  17  C/P Score.4         1240 non-null   int64
#  18  CARS Score.4        1240 non-null   int64
#  19  B/B Score.4         1240 non-null   int64
#  20  P/S Score.4         1240 non-null   int64
# dtypes: int64(21)
# memory usage: 213.1 KB
#    Real Score  Days Before Exam.1  C/P Score.1  CARS Score.1  B/B Score.1  \
# 3         515                   7          129           128          128
# 4         522                   8          131           129          128
# 5         524                   6          131           130          132
# 7         518                   7          129           130          127
# 8         507                   7          128           128          128
#
#    P/S Score.1  Days Before Exam.2  C/P Score.2  CARS Score.2  B/B Score.2  \
# 3          130                  14          127           126          128
# 4          131                  11          131           128          128
# 5          131                  10          131           127          131
# 7          126                  14          128           129          127
# 8          128                  14          130           130          130
#
#    ...  Days Before Exam.3  C/P Score.3  CARS Score.3  B/B Score.3  \
# 3  ...                  21          127           127          129
# 4  ...                   4          130           129          130
# 5  ...                  24          132           130          130
# 7  ...                  23          125           130          127
# 8  ...                  21          128           129          128
#
#    P/S Score.3  Days Before Exam.4  C/P Score.4  CARS Score.4  B/B Score.4  \
# 3          127                  28          127           125          127
# 4          131                  15          129           130          129
# 5          130                  90          130           128          130
# 7          124                  91          125           130          125
# 8          128                  28          129           132          130
#
#    P/S Score.4
# 3          127
# 4          131
# 5          131
# 7          124
# 8          130
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Clean Data and Add New Features

# %%
# drop rows with impossible values
#                # days before exam > 180
#                # exact duplicate values to another row
#                # impossible scores (>528 total or >132 on any subsection)
remove_indices = []
remove_indices.extend(scores[scores['Real Score']>528].index.values)
remove_indices.extend(scores[scores['Real Score']<472].index.values)
for i in range(1, 5):
    remove_indices.extend(scores[scores['Days Before Exam.'+str(i)]>200].index.values)
    remove_indices.extend(scores[scores['Days Before Exam.'+str(i)]<0].index.values)
    remove_indices.extend(scores[scores['C/P Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['C/P Score.'+str(i)]<118].index.values)
    remove_indices.extend(scores[scores['CARS Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['CARS Score.'+str(i)]<118].index.values)
    remove_indices.extend(scores[scores['B/B Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['B/B Score.'+str(i)]<118].index.values)
    remove_indices.extend(scores[scores['P/S Score.'+str(i)]>132].index.values)
    remove_indices.extend(scores[scores['P/S Score.'+str(i)]<118].index.values)

# remove duplicate indices
remove_indices = list(dict.fromkeys(remove_indices))

# delete all rows with impossible values
for i in remove_indices:
    scores.drop(i, axis = 0, inplace = True)

scores.info()
scores.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1218 entries, 3 to 4297
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Real Score          1218 non-null   int64
#  1   Days Before Exam.1  1218 non-null   int64
#  2   C/P Score.1         1218 non-null   int64
#  3   CARS Score.1        1218 non-null   int64
#  4   B/B Score.1         1218 non-null   int64
#  5   P/S Score.1         1218 non-null   int64
#  6   Days Before Exam.2  1218 non-null   int64
#  7   C/P Score.2         1218 non-null   int64
#  8   CARS Score.2        1218 non-null   int64
#  9   B/B Score.2         1218 non-null   int64
#  10  P/S Score.2         1218 non-null   int64
#  11  Days Before Exam.3  1218 non-null   int64
#  12  C/P Score.3         1218 non-null   int64
#  13  CARS Score.3        1218 non-null   int64
#  14  B/B Score.3         1218 non-null   int64
#  15  P/S Score.3         1218 non-null   int64
#  16  Days Before Exam.4  1218 non-null   int64
#  17  C/P Score.4         1218 non-null   int64
#  18  CARS Score.4        1218 non-null   int64
#  19  B/B Score.4         1218 non-null   int64
#  20  P/S Score.4         1218 non-null   int64
# dtypes: int64(21)
# memory usage: 209.3 KB
#    Real Score  Days Before Exam.1  C/P Score.1  CARS Score.1  B/B Score.1  \
# 3         515                   7          129           128          128
# 4         522                   8          131           129          128
# 5         524                   6          131           130          132
# 7         518                   7          129           130          127
# 8         507                   7          128           128          128
#
#    P/S Score.1  Days Before Exam.2  C/P Score.2  CARS Score.2  B/B Score.2  \
# 3          130                  14          127           126          128
# 4          131                  11          131           128          128
# 5          131                  10          131           127          131
# 7          126                  14          128           129          127
# 8          128                  14          130           130          130
#
#    ...  Days Before Exam.3  C/P Score.3  CARS Score.3  B/B Score.3  \
# 3  ...                  21          127           127          129
# 4  ...                   4          130           129          130
# 5  ...                  24          132           130          130
# 7  ...                  23          125           130          127
# 8  ...                  21          128           129          128
#
#    P/S Score.3  Days Before Exam.4  C/P Score.4  CARS Score.4  B/B Score.4  \
# 3          127                  28          127           125          127
# 4          131                  15          129           130          129
# 5          130                  90          130           128          130
# 7          124                  91          125           130          125
# 8          128                  28          129           132          130
#
#    P/S Score.4
# 3          127
# 4          131
# 5          131
# 7          124
# 8          130
#
# [5 rows x 21 columns]

# %%
# define features and labels from the observations
features = scores.columns[1:len(scores)]
X = scores[features].values.reshape(-1, len(features))
y = scores["Real Score"].to_numpy()
print(X.shape,y.shape)
# Out:
# (1218, 20) (1218,)

# %% [markdown]
# # Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split
from scipy.stats import ks_2samp

#split data into training and testing, fix random_state so output is the same every run
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True,
                                   test_size=0.20, random_state=5)

#We define a function to see if our two sets are distributed evenly for every features
def check_distributions(X1,X2):
    pVals = np.zeros((X1.shape[1]))
    for i in np.arange(X1.shape[1]):
        kstat,pvalue = ks_2samp(X1[:,i],X2[:,i])
        pVals[i]=pvalue
    print("Mean of pvalues :", np.mean(pVals))
    print("Smallest pvalue :",np.amin(pVals)) 
    #return(pVals)

#sanity check: look at how many data points are in train/test and if our pvalues are acceptable
print(X_train.shape[0])
print(X_test.shape[0])
check_distributions(X_train,X_test)
# Out:
# 974
# 244
# Mean of pvalues : 0.6322802575997795
# Smallest pvalue : 0.012233060909428621

# %% [markdown]
# ## Visualize Correlations

# %%
# create a correlation matrix with pandas
corr_matrix = scores.corr()
corr_matrix['Real Score'].sort_values(ascending=False)

# create scatter matrices displaying totals, medians.
from pandas.plotting import scatter_matrix

attributes = ['Real Score', 'CARS Score.1', 'CARS Score.2', 'CARS Score.3', 'CARS Score.4']
scatter_matrix(scores[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='Real Score', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='Real Score'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='Real Score'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.1'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.1'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.2'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.2'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.3'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.3'>],
#        [<AxesSubplot:xlabel='Real Score', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.1', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.2', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.3', ylabel='CARS Score.4'>,
#         <AxesSubplot:xlabel='CARS Score.4', ylabel='CARS Score.4'>]],
#       dtype=object)

# %% [markdown]
# # Linear Regression
# ## Define Model Validation Function

# %%
def model_validation(X, y, results_list, scores_list):
    lin_reg = LinearRegression()
    scoring = "neg_mean_squared_error"
    results_dictionary = cross_validate(lin_reg, X, y, scoring=scoring, cv=4, return_estimator=True)
    results_list.append(results_dictionary)
    mean_score = results_dictionary["test_score"].mean()
    scores_list.append(mean_score)

# %% [markdown]
# ## PCA to Create Linear Combinations of Features

# %%
from sklearn.decomposition import PCA

# fit the PCA
N = 12
pca = PCA(n_components=N)
pca.fit_transform(X_train)

# plot the explained variances
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'tab:blue'
ax1.bar(1+np.arange(N), pca.explained_variance_ratio_, color=color)
ax1.set_xticks(1+np.arange(N, step=2))
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylabel("Explained variance ratio", color=color)
ax1.set_xlabel("Generated feature")

ax2 = ax1.twinx()
color = 'tab:red'
ax2.tick_params(axis='y', labelcolor=color)
ax2.plot(1+np.arange(N), np.cumsum(pca.explained_variance_ratio_), color=color)
ax2.set_ylabel("Cumulative explained variance ratio", color=color)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## K-fold Cross Validation

# %%
# results stores the dictionary returned by the cross validation
# results thus becomes a list of dictionaries
# nmse stores the *mean* of all the neg_mean_squared_error's from each of k runs
results = []
nmse = []

# Linear Regression without Dimensionality Reduction
model_validation(X_train, y_train, results, nmse)
# Linear Regression with Dimensionality Reduction
for n in range(X_train.shape[1]):
    pca = PCA(n_components=n+1)
    X_train_reduced = pca.fit_transform(X_train)
    model_validation(X_train_reduced, y_train, results, nmse)
# Display the results
for i in range(0, len(nmse), 1):
    if i == 0:
        print("neg mean squared error of linear regression: ", nmse[i])
    else:
        print("neg mean squared error of linear regression with ", i, " dimensions is ", nmse[i])
# Out:
# neg mean squared error of linear regression:  -8.440594881077468
# neg mean squared error of linear regression with  1  dimensions is  -28.831759758998928
# neg mean squared error of linear regression with  2  dimensions is  -29.078621195303377
# neg mean squared error of linear regression with  3  dimensions is  -29.09012431436057
# neg mean squared error of linear regression with  4  dimensions is  -29.168987765616947
# neg mean squared error of linear regression with  5  dimensions is  -9.02078743473586
# neg mean squared error of linear regression with  6  dimensions is  -8.88849550065298
# neg mean squared error of linear regression with  7  dimensions is  -8.762193746806762
# neg mean squared error of linear regression with  8  dimensions is  -8.597365760318612
# neg mean squared error of linear regression with  9  dimensions is  -8.491385562087146
# neg mean squared error of linear regression with  10  dimensions is  -8.427892657134493
# neg mean squared error of linear regression with  11  dimensions is  -8.439737659043937
# neg mean squared error of linear regression with  12  dimensions is  -8.432599742141575
# neg mean squared error of linear regression with  13  dimensions is  -8.43879239303296
# neg mean squared error of linear regression with  14  dimensions is  -8.447937446163035
# neg mean squared error of linear regression with  15  dimensions is  -8.44013614290938
# neg mean squared error of linear regression with  16  dimensions is  -8.4553124757365
# neg mean squared error of linear regression with  17  dimensions is  -8.474118306497747
# neg mean squared error of linear regression with  18  dimensions is  -8.478972841976802
# neg mean squared error of linear regression with  19  dimensions is  -8.474609865407178
# neg mean squared error of linear regression with  20  dimensions is  -8.440594881077457

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## K-fold Cross Validation

# %%
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# Train the model on training data and validate data using k-fold cross validation
scoring = "neg_mean_squared_error"
rf_results_dictionary = cross_validate(rf, X_train, y_train, scoring=scoring, cv=4, return_estimator=True)
rf_mean_score = rf_results_dictionary["test_score"].mean()
print(rf_mean_score)
# Out:
# -9.145848762084261

# %% [markdown]
# # Evaluate the Metrics of the Best Model

# %%
#The choosed model is PCA with 10 components
pca = PCA(n_components=10)
X_train_reduced = pca.fit_transform(X_train)

# train the model on all the training data
lin_reg1 = LinearRegression()
lin_reg1 = lin_reg1.fit(X_train_reduced, y_train)

# transform the testing data to the same space as the training data
X_test_reduced = pca.transform(X_test)

# evaluate the model's accuracy using the test data
R2 = lin_reg1.score(X_test_reduced, y_test)
print(f"The coefficient of determination: {R2:.2f}")

# use loss function on prediction vs. test
y_pred = lin_reg1.predict(X_test_reduced)
mse = mean_squared_error(y_test, y_pred)
print("neg mean squared error of the final ML model: ", -mse)
# Out:
# The coefficient of determination: 0.76
# neg mean squared error of the final ML model:  -8.489626361739898

# %%
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred_rf)
print("neg mean squared error of the final ML model: ", -mse)
# Out:
# neg mean squared error of the final ML model:  -9.7502445081967

# %% [markdown]
# # Data visualisation

# %% [markdown]
# ## Rearrange X_reduced

# %%
from scipy.stats import linregress
print(X_train_reduced[0].shape, y_train.shape)
r_values = []
for compo in range(10):
    slope, intercept, r_value, p_value, std_err = linregress(X_train_reduced[:,compo], y_train)
    r_value = -np.abs(r_value)
    r_values.append(r_value)
order = np.argsort(r_values)
X_train_reduced = X_train_reduced[:,order]
# Out:
# (10,) (974,)

# %% [markdown]
# ## Display PCA1, PCA2 and colored labels

# %%
plt.figure(figsize=(7, 3))
# convert the labels to numbers, each will be assigned a separate color based on the cmap specified
colors = [int(x) for x in y_train]
sc = plt.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], c=colors)#,s=1 cmap='tab10')
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend(*sc.legend_elements(), title='digit')
plt.show()

# %%
import plotly.express as px
colors = y_train
fig = px.scatter(X_train_reduced, x=0, y=1, color=colors)
fig.update_layout(xaxis_title="PCA 1", yaxis_title="PCA 2",legend=dict(title="Final score"))#legend_title_text='Final score')
fig.show()

# %%
#3D plotting
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], X_train_reduced[:,2], c=colors)
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('PCA 3')
plt.legend(*sc.legend_elements(), title='digit',loc="upper right")
plt.show()

# %% [markdown]
# ## Results in function of pca components

# %%
#3D plotting
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
ax.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], y_train)#, c=colors)
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel("Final score")
#plt.legend(*sc.legend_elements(), title='digit',loc="upper center")
plt.title("Final scores at exam of the training set in function of PCA1 and PCA2 parameters")

coefs = lin_reg1.coef_
intercept = lin_reg1.intercept_
xs = np.arange(-15,10,15)
ys = np.arange(-50,10,250)
zs = xs*coefs[0]+ys*coefs[1]+intercept
#print("Equation: y = {:.2f} + {:.2f}x1 + {:.2f}x2".format(intercept, coefs[0],coefs[1]))

ax.plot_surface(xs,ys,zs, alpha=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [74], in <cell line: 18>()
#      15 zs = xs*coefs[0]+ys*coefs[1]+intercept
#      16 #print("Equation: y = {:.2f} + {:.2f}x1 + {:.2f}x2".format(intercept, coefs[0],coefs[1]))
# ---> 18 ax.plot_surface(xs,ys,zs, alpha=0.5)
#      20 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py:1581, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578 had_data = self.has_data()
#    1580 if Z.ndim != 2:
# -> 1581     raise ValueError("Argument Z must be 2-dimensional.")
#    1583 Z = cbook._to_unmasked_float_array(Z)
#    1584 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
#total_var = pca.explained_variance_ratio_.sum() * 100

fig = px.scatter_3d(
    X_train_reduced, x=0, y=1, z=y_train, color=colors,
    title='Final scores at exam of the training set in function of PCA1 and PCA2 parameters',
    labels={'0': 'PC 1', '1': 'PC 2', '2': 'PC 3'}
)
fig.update_layout(
    autosize=False,
    width=700,
    height=500)
fig.show()

# %%
plt.figure(figsize=(6, 6))
# convert the labels to numbers, each will be assigned a separate color based on the cmap specified
colors = [int(x) for x in y_train]
sc = plt.scatter(X_train_reduced[:, 0],y_train)#, c=colors)#,s=1 cmap='tab10')
plt.xlabel("PCA1")
plt.ylabel("Final score")
#plt.legend(*sc.legend_elements(), title='digit')
plt.title("Final scores at exam of the training set in function of PCA1 parameter")
plt.show()

# %% [markdown]
# ## Visualize RF Tree

# %%
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(15, 10))
plot_tree(rf.estimators_[0], 
          feature_names = features,
          filled = True, impurity = True, 
          rounded = True)

#from sklearn.tree import export_text

#print(export_text(rf.estimators_[0], 
                  #spacing=3, decimals=3,
                  #feature_names=features))
# Out:
# [Text(0.4311640062239353, 0.975, 'C/P Score.1 <= 129.5\nsquared_error = 28.12\nsamples = 610\nvalue = 517.958'),
#  Text(0.19766622172374573, 0.925, 'P/S Score.1 <= 127.5\nsquared_error = 25.853\nsamples = 262\nvalue = 514.527'),
#  Text(0.08005813218753949, 0.875, 'P/S Score.3 <= 126.5\nsquared_error = 23.168\nsamples = 61\nvalue = 510.02'),
#  Text(0.045494755465689374, 0.825, 'B/B Score.1 <= 130.5\nsquared_error = 21.339\nsamples = 34\nvalue = 508.018'),
#  Text(0.043472766333880954, 0.775, 'Days Before Exam.4 <= 20.0\nsquared_error = 12.924\nsamples = 33\nvalue = 508.865'),
#  Text(0.02224188044989258, 0.725, 'C/P Score.1 <= 127.5\nsquared_error = 5.433\nsamples = 14\nvalue = 511.043'),
#  Text(0.013142929356754707, 0.675, 'C/P Score.3 <= 127.5\nsquared_error = 3.743\nsamples = 7\nvalue = 509.583'),
#  Text(0.008087956527233667, 0.625, 'C/P Score.4 <= 126.5\nsquared_error = 1.728\nsamples = 5\nvalue = 508.778'),
#  Text(0.004043978263616833, 0.575, 'CARS Score.3 <= 125.5\nsquared_error = 0.56\nsamples = 3\nvalue = 509.8'),
#  Text(0.0020219891318084167, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.006065967395425249, 0.525, 'B/B Score.3 <= 126.5\nsquared_error = 0.222\nsamples = 2\nvalue = 510.333'),
#  Text(0.004043978263616833, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.008087956527233667, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.012131934790850498, 0.575, 'Days Before Exam.3 <= 10.0\nsquared_error = 0.25\nsamples = 2\nvalue = 507.5'),
#  Text(0.010109945659042083, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.014153923922658915, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.01819790218627575, 0.625, 'CARS Score.1 <= 127.0\nsquared_error = 2.0\nsamples = 2\nvalue = 512.0'),
#  Text(0.016175913054467334, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.020219891318084167, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.031340831543030453, 0.675, 'P/S Score.2 <= 126.0\nsquared_error = 2.413\nsamples = 7\nvalue = 512.636'),
#  Text(0.026285858713509413, 0.625, 'CARS Score.3 <= 124.5\nsquared_error = 0.222\nsamples = 2\nvalue = 510.333'),
#  Text(0.024263869581700997, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.02830784784531783, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.0363958043725515, 0.625, 'B/B Score.2 <= 128.5\nsquared_error = 0.5\nsamples = 5\nvalue = 513.5'),
#  Text(0.03235182610893467, 0.575, 'P/S Score.4 <= 126.0\nsquared_error = 0.25\nsamples = 2\nvalue = 514.5'),
#  Text(0.030329836977126247, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.03437381524074308, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.040439782636168334, 0.575, 'P/S Score.3 <= 125.5\nsquared_error = 0.139\nsamples = 3\nvalue = 513.167'),
#  Text(0.038417793504359914, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.04246177176797675, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.06470365221786933, 0.725, 'CARS Score.1 <= 125.5\nsquared_error = 12.119\nsamples = 19\nvalue = 507.138'),
#  Text(0.05156072286111462, 0.675, 'C/P Score.3 <= 125.5\nsquared_error = 5.209\nsamples = 9\nvalue = 504.071'),
#  Text(0.04650575003159358, 0.625, 'Days Before Exam.1 <= 5.0\nsquared_error = 1.688\nsamples = 2\nvalue = 501.25'),
#  Text(0.04448376089978516, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 502.0'),
#  Text(0.048527739163401994, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 499.0'),
#  Text(0.05661569569063566, 0.625, 'P/S Score.4 <= 123.5\nsquared_error = 2.16\nsamples = 7\nvalue = 505.2'),
#  Text(0.05257171742701883, 0.575, 'C/P Score.4 <= 125.0\nsquared_error = 0.222\nsamples = 2\nvalue = 503.333'),
#  Text(0.050549728295210414, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 503.0'),
#  Text(0.05459370655882725, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 504.0'),
#  Text(0.060659673954252494, 0.575, 'CARS Score.4 <= 123.5\nsquared_error = 0.857\nsamples = 5\nvalue = 506.0'),
#  Text(0.05863768482244408, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 507.0'),
#  Text(0.06268166308606091, 0.525, 'Days Before Exam.2 <= 10.5\nsquared_error = 0.188\nsamples = 3\nvalue = 505.25'),
#  Text(0.060659673954252494, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.06470365221786933, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 505.0'),
#  Text(0.07784658157462404, 0.675, 'Days Before Exam.4 <= 58.5\nsquared_error = 1.6\nsamples = 10\nvalue = 510.0'),
#  Text(0.072791608745103, 0.625, 'CARS Score.2 <= 126.5\nsquared_error = 0.583\nsamples = 7\nvalue = 509.5'),
#  Text(0.06874763048148616, 0.575, 'C/P Score.1 <= 127.0\nsquared_error = 0.16\nsamples = 3\nvalue = 508.8'),
#  Text(0.06672564134967775, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.07076961961329457, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 509.0'),
#  Text(0.07683558700871983, 0.575, 'Days Before Exam.3 <= 12.0\nsquared_error = 0.286\nsamples = 4\nvalue = 510.0'),
#  Text(0.07481359787691141, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.07885757614052824, 0.525, 'Days Before Exam.2 <= 9.5\nsquared_error = 0.139\nsamples = 3\nvalue = 510.167'),
#  Text(0.07683558700871983, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.08087956527233667, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 510.0'),
#  Text(0.08290155440414508, 0.625, 'Days Before Exam.2 <= 22.5\nsquared_error = 0.667\nsamples = 3\nvalue = 512.0'),
#  Text(0.08087956527233667, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.0849235435359535, 0.575, 'C/P Score.3 <= 125.0\nsquared_error = 0.25\nsamples = 2\nvalue = 511.5'),
#  Text(0.08290155440414508, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.08694553266776191, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.04751674459749779, 0.775, 'squared_error = 0.0\nsamples = 1\nvalue = 497.0'),
#  Text(0.11462150890938962, 0.825, 'C/P Score.3 <= 125.5\nsquared_error = 14.25\nsamples = 27\nvalue = 512.511'),
#  Text(0.10767092126879818, 0.775, 'Days Before Exam.3 <= 16.5\nsquared_error = 2.25\nsamples = 3\nvalue = 505.5'),
#  Text(0.10564893213698977, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.1096929104006066, 0.725, 'squared_error = 0.0\nsamples = 2\nvalue = 504.0'),
#  Text(0.12157209654998104, 0.775, 'C/P Score.3 <= 129.5\nsquared_error = 10.157\nsamples = 24\nvalue = 513.195'),
#  Text(0.11373688866422343, 0.725, 'C/P Score.1 <= 127.5\nsquared_error = 7.914\nsamples = 22\nvalue = 513.757'),
#  Text(0.10413244028813345, 0.675, 'C/P Score.2 <= 127.5\nsquared_error = 6.413\nsamples = 13\nvalue = 512.364'),
#  Text(0.09705547832680399, 0.625, 'Days Before Exam.4 <= 27.5\nsquared_error = 2.556\nsamples = 8\nvalue = 510.667'),
#  Text(0.09301150006318716, 0.575, 'B/B Score.2 <= 126.5\nsquared_error = 1.347\nsamples = 4\nvalue = 511.714'),
#  Text(0.09098951093137875, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.09503348919499557, 0.525, 'Days Before Exam.2 <= 8.5\nsquared_error = 0.24\nsamples = 3\nvalue = 512.4'),
#  Text(0.09301150006318716, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 512.0'),
#  Text(0.09705547832680399, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.10109945659042083, 0.575, 'CARS Score.2 <= 124.0\nsquared_error = 0.56\nsamples = 4\nvalue = 509.2'),
#  Text(0.09907746745861241, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.10312144572222924, 0.525, 'P/S Score.1 <= 126.0\nsquared_error = 0.222\nsamples = 3\nvalue = 508.667'),
#  Text(0.10109945659042083, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.10514343485403765, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 509.0'),
#  Text(0.11120940224946291, 0.625, 'Days Before Exam.2 <= 4.0\nsquared_error = 3.44\nsamples = 5\nvalue = 514.4'),
#  Text(0.1091874131176545, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.11323139138127132, 0.575, 'P/S Score.2 <= 130.5\nsquared_error = 1.21\nsamples = 4\nvalue = 513.889'),
#  Text(0.11120940224946291, 0.525, 'CARS Score.2 <= 127.5\nsquared_error = 0.245\nsamples = 3\nvalue = 514.429'),
#  Text(0.1091874131176545, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.11323139138127132, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.11525338051307975, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.12334133704031341, 0.675, 'CARS Score.1 <= 125.5\nsquared_error = 3.093\nsamples = 9\nvalue = 515.8'),
#  Text(0.12131934790850499, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.12536332617212181, 0.625, 'CARS Score.2 <= 129.5\nsquared_error = 2.178\nsamples = 8\nvalue = 516.231'),
#  Text(0.12131934790850499, 0.575, 'CARS Score.4 <= 126.0\nsquared_error = 0.438\nsamples = 5\nvalue = 517.25'),
#  Text(0.11929735877669657, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.12334133704031341, 0.525, 'squared_error = 0.0\nsamples = 4\nvalue = 517.0'),
#  Text(0.12940730443573867, 0.575, 'CARS Score.4 <= 128.5\nsquared_error = 0.64\nsamples = 3\nvalue = 514.6'),
#  Text(0.12738531530393024, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.13142929356754707, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.12940730443573867, 0.725, 'Days Before Exam.4 <= 35.5\nsquared_error = 1.0\nsamples = 2\nvalue = 508.0'),
#  Text(0.12738531530393024, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.13142929356754707, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 507.0'),
#  Text(0.315274311259952, 0.875, 'CARS Score.1 <= 128.5\nsquared_error = 18.203\nsamples = 201\nvalue = 515.959'),
#  Text(0.23992164792114243, 0.825, 'B/B Score.1 <= 128.5\nsquared_error = 17.544\nsamples = 102\nvalue = 514.075'),
#  Text(0.1947428282572981, 0.775, 'Days Before Exam.4 <= 46.5\nsquared_error = 13.231\nsamples = 52\nvalue = 512.265'),
#  Text(0.16706685201567043, 0.725, 'C/P Score.4 <= 126.5\nsquared_error = 8.416\nsamples = 41\nvalue = 513.441'),
#  Text(0.145583217490206, 0.675, 'C/P Score.3 <= 127.5\nsquared_error = 9.121\nsamples = 13\nvalue = 511.235'),
#  Text(0.14356122835839757, 0.625, 'C/P Score.2 <= 126.5\nsquared_error = 6.196\nsamples = 12\nvalue = 511.933'),
#  Text(0.13749526096297232, 0.575, 'Days Before Exam.2 <= 14.5\nsquared_error = 3.265\nsamples = 5\nvalue = 509.857'),
#  Text(0.1354732718311639, 0.525, 'CARS Score.3 <= 127.5\nsquared_error = 0.917\nsamples = 4\nvalue = 510.5'),
#  Text(0.13142929356754707, 0.475, 'C/P Score.1 <= 127.0\nsquared_error = 0.222\nsamples = 2\nvalue = 511.333'),
#  Text(0.12940730443573867, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.1334512826993555, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.13951725009478075, 0.475, 'B/B Score.1 <= 126.5\nsquared_error = 0.222\nsamples = 2\nvalue = 509.667'),
#  Text(0.13749526096297232, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.14153923922658915, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.13951725009478075, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.14962719575382283, 0.575, 'B/B Score.1 <= 126.5\nsquared_error = 1.688\nsamples = 7\nvalue = 513.75'),
#  Text(0.145583217490206, 0.525, 'CARS Score.3 <= 129.5\nsquared_error = 0.25\nsamples = 2\nvalue = 515.5'),
#  Text(0.14356122835839757, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.1476052066220144, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.15367117401743965, 0.525, 'CARS Score.4 <= 127.0\nsquared_error = 0.806\nsamples = 5\nvalue = 513.167'),
#  Text(0.15164918488563123, 0.475, 'C/P Score.4 <= 124.0\nsquared_error = 0.188\nsamples = 3\nvalue = 513.75'),
#  Text(0.14962719575382283, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.15367117401743965, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.15569316314924808, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 512.0'),
#  Text(0.1476052066220144, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.18855048654113485, 0.675, 'CARS Score.1 <= 127.5\nsquared_error = 5.365\nsamples = 28\nvalue = 514.333'),
#  Text(0.17389106533552381, 0.625, 'CARS Score.4 <= 126.5\nsquared_error = 2.718\nsamples = 17\nvalue = 513.321'),
#  Text(0.16580310880829016, 0.575, 'CARS Score.2 <= 125.5\nsquared_error = 1.662\nsamples = 9\nvalue = 512.267'),
#  Text(0.16175913054467334, 0.525, 'B/B Score.1 <= 127.5\nsquared_error = 0.25\nsamples = 5\nvalue = 511.5'),
#  Text(0.1597371414128649, 0.475, 'squared_error = 0.0\nsamples = 3\nvalue = 512.0'),
#  Text(0.16378111967648173, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 511.0'),
#  Text(0.169847087071907, 0.525, 'P/S Score.1 <= 128.5\nsquared_error = 0.96\nsamples = 4\nvalue = 513.8'),
#  Text(0.16782509794009856, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.17186907620371542, 0.475, 'Days Before Exam.4 <= 29.0\nsquared_error = 0.188\nsamples = 3\nvalue = 514.25'),
#  Text(0.169847087071907, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.17389106533552381, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.1819790218627575, 0.575, 'Days Before Exam.1 <= 4.5\nsquared_error = 1.172\nsamples = 8\nvalue = 514.538'),
#  Text(0.17793504359914064, 0.525, 'B/B Score.2 <= 128.0\nsquared_error = 0.49\nsamples = 4\nvalue = 513.714'),
#  Text(0.17591305446733224, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.17995703273094907, 0.475, 'P/S Score.3 <= 129.0\nsquared_error = 0.25\nsamples = 3\nvalue = 513.5'),
#  Text(0.17793504359914064, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.1819790218627575, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.18602300012637432, 0.525, 'B/B Score.1 <= 127.5\nsquared_error = 0.25\nsamples = 4\nvalue = 515.5'),
#  Text(0.1840010109945659, 0.475, 'squared_error = 0.0\nsamples = 3\nvalue = 515.0'),
#  Text(0.18804498925818275, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.20320990774674585, 0.625, 'B/B Score.2 <= 129.5\nsquared_error = 4.515\nsamples = 11\nvalue = 516.357'),
#  Text(0.19815493491722483, 0.575, 'C/P Score.4 <= 127.5\nsquared_error = 1.653\nsamples = 8\nvalue = 517.273'),
#  Text(0.19411095665360797, 0.525, 'Days Before Exam.4 <= 37.0\nsquared_error = 0.5\nsamples = 3\nvalue = 516.0'),
#  Text(0.19208896752179958, 0.475, 'Days Before Exam.3 <= 17.0\nsquared_error = 0.222\nsamples = 2\nvalue = 515.667'),
#  Text(0.19006697838999115, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.19411095665360797, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.1961329457854164, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.20219891318084166, 0.525, 'P/S Score.2 <= 128.0\nsquared_error = 0.857\nsamples = 5\nvalue = 518.0'),
#  Text(0.20017692404903323, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.20422090231265008, 0.475, 'C/P Score.4 <= 128.5\nsquared_error = 0.188\nsamples = 4\nvalue = 518.75'),
#  Text(0.20219891318084166, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 519.0'),
#  Text(0.20624289144445848, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.2082648805762669, 0.575, 'CARS Score.3 <= 128.5\nsquared_error = 0.667\nsamples = 3\nvalue = 513.0'),
#  Text(0.20624289144445848, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.2102868697080753, 0.525, 'C/P Score.4 <= 128.5\nsquared_error = 0.25\nsamples = 2\nvalue = 512.5'),
#  Text(0.2082648805762669, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.21230885883988374, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.22241880449892582, 0.725, 'Days Before Exam.2 <= 18.0\nsquared_error = 13.318\nsamples = 11\nvalue = 509.375'),
#  Text(0.21635283710350056, 0.675, 'B/B Score.1 <= 125.5\nsquared_error = 2.59\nsamples = 7\nvalue = 511.312'),
#  Text(0.21433084797169216, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.218374826235309, 0.625, 'Days Before Exam.4 <= 115.5\nsquared_error = 1.168\nsamples = 6\nvalue = 511.786'),
#  Text(0.21635283710350056, 0.575, 'Days Before Exam.3 <= 40.5\nsquared_error = 0.16\nsamples = 3\nvalue = 513.2'),
#  Text(0.21433084797169216, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.218374826235309, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.2203968153671174, 0.575, 'squared_error = 0.0\nsamples = 3\nvalue = 511.0'),
#  Text(0.22848477189435107, 0.675, 'Days Before Exam.4 <= 160.0\nsquared_error = 12.25\nsamples = 4\nvalue = 505.5'),
#  Text(0.22646278276254264, 0.625, 'B/B Score.3 <= 127.5\nsquared_error = 2.204\nsamples = 3\nvalue = 504.286'),
#  Text(0.22444079363073424, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 502.0'),
#  Text(0.22848477189435107, 0.575, 'B/B Score.4 <= 127.5\nsquared_error = 0.16\nsamples = 2\nvalue = 505.2'),
#  Text(0.22646278276254264, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 506.0'),
#  Text(0.2305067610261595, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 505.0'),
#  Text(0.2305067610261595, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.28510046758498675, 0.775, 'CARS Score.3 <= 129.5\nsquared_error = 14.856\nsamples = 50\nvalue = 516.026'),
#  Text(0.2648805762669026, 0.725, 'C/P Score.4 <= 130.5\nsquared_error = 11.947\nsamples = 39\nvalue = 514.649'),
#  Text(0.26285858713509413, 0.675, 'CARS Score.4 <= 126.5\nsquared_error = 9.26\nsamples = 38\nvalue = 515.151'),
#  Text(0.24921016049538733, 0.625, 'P/S Score.1 <= 129.5\nsquared_error = 5.583\nsamples = 17\nvalue = 513.5'),
#  Text(0.23960571211929735, 0.575, 'B/B Score.4 <= 127.0\nsquared_error = 3.537\nsamples = 8\nvalue = 511.909'),
#  Text(0.23455073928977632, 0.525, 'P/S Score.1 <= 128.5\nsquared_error = 2.24\nsamples = 3\nvalue = 513.4'),
#  Text(0.2325287501579679, 0.475, 'Days Before Exam.3 <= 20.0\nsquared_error = 0.889\nsamples = 2\nvalue = 512.333'),
#  Text(0.2305067610261595, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.23455073928977632, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.23657272842158472, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.2446606849488184, 0.525, 'B/B Score.4 <= 129.5\nsquared_error = 1.222\nsamples = 5\nvalue = 510.667'),
#  Text(0.24061670668520158, 0.475, 'CARS Score.2 <= 127.5\nsquared_error = 0.222\nsamples = 3\nvalue = 509.667'),
#  Text(0.23859471755339315, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 510.0'),
#  Text(0.24263869581700998, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.24870466321243523, 0.475, 'P/S Score.3 <= 127.5\nsquared_error = 0.222\nsamples = 2\nvalue = 511.667'),
#  Text(0.24668267408062683, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.25072665234424363, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.25881460887147734, 0.575, 'CARS Score.4 <= 124.5\nsquared_error = 3.361\nsamples = 9\nvalue = 514.846'),
#  Text(0.2567926197396689, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.26083659800328574, 0.525, 'P/S Score.2 <= 130.5\nsquared_error = 1.243\nsamples = 8\nvalue = 514.417'),
#  Text(0.2567926197396689, 0.475, 'P/S Score.3 <= 126.5\nsquared_error = 0.188\nsamples = 4\nvalue = 513.25'),
#  Text(0.2547706306078605, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.25881460887147734, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 513.0'),
#  Text(0.2648805762669026, 0.475, 'C/P Score.2 <= 129.5\nsquared_error = 0.75\nsamples = 4\nvalue = 515.0'),
#  Text(0.26285858713509413, 0.425, 'C/P Score.4 <= 125.0\nsquared_error = 0.24\nsamples = 3\nvalue = 515.6'),
#  Text(0.26083659800328574, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.2648805762669026, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 516.0'),
#  Text(0.266902565398711, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.27650701377480097, 0.625, 'B/B Score.2 <= 127.5\nsquared_error = 8.181\nsamples = 21\nvalue = 516.517'),
#  Text(0.2689245545305194, 0.575, 'C/P Score.4 <= 126.0\nsquared_error = 3.76\nsamples = 3\nvalue = 512.8'),
#  Text(0.266902565398711, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.2709465436623278, 0.525, 'B/B Score.3 <= 126.5\nsquared_error = 0.188\nsamples = 2\nvalue = 513.75'),
#  Text(0.2689245545305194, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.27296853279413624, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.28408947301908255, 0.575, 'Days Before Exam.2 <= 11.0\nsquared_error = 5.623\nsamples = 18\nvalue = 517.292'),
#  Text(0.2790345001895615, 0.525, 'B/B Score.4 <= 130.5\nsquared_error = 5.959\nsamples = 5\nvalue = 515.429'),
#  Text(0.27701251105775304, 0.475, 'Days Before Exam.2 <= 7.5\nsquared_error = 2.889\nsamples = 4\nvalue = 514.667'),
#  Text(0.27499052192594464, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.2790345001895615, 0.425, 'Days Before Exam.1 <= 4.0\nsquared_error = 0.24\nsamples = 3\nvalue = 515.4'),
#  Text(0.27701251105775304, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.2810564893213699, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.2810564893213699, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.28914444584860355, 0.525, 'Days Before Exam.3 <= 18.0\nsquared_error = 3.467\nsamples = 13\nvalue = 518.059'),
#  Text(0.28510046758498675, 0.475, 'CARS Score.1 <= 127.5\nsquared_error = 0.96\nsamples = 4\nvalue = 519.8'),
#  Text(0.2830784784531783, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.28712245671679515, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 519.0'),
#  Text(0.2931884241122204, 0.475, 'C/P Score.2 <= 130.5\nsquared_error = 2.722\nsamples = 9\nvalue = 517.333'),
#  Text(0.291166434980412, 0.425, 'B/B Score.4 <= 129.5\nsquared_error = 1.636\nsamples = 8\nvalue = 517.0'),
#  Text(0.28611146215089095, 0.375, 'C/P Score.1 <= 127.5\nsquared_error = 0.734\nsamples = 6\nvalue = 517.625'),
#  Text(0.2820674838872741, 0.325, 'P/S Score.2 <= 128.5\nsquared_error = 0.25\nsamples = 2\nvalue = 516.5'),
#  Text(0.2800454947554657, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.28408947301908255, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.29015544041450775, 0.325, 'Days Before Exam.4 <= 78.0\nsquared_error = 0.333\nsamples = 4\nvalue = 518.0'),
#  Text(0.28813345128269935, 0.275, 'Days Before Exam.3 <= 34.0\nsquared_error = 0.16\nsamples = 3\nvalue = 518.2'),
#  Text(0.28611146215089095, 0.225, 'squared_error = 0.0\nsamples = 2\nvalue = 518.0'),
#  Text(0.29015544041450775, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.2921774295463162, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.296221407809933, 0.375, 'CARS Score.3 <= 125.5\nsquared_error = 0.222\nsamples = 2\nvalue = 515.333'),
#  Text(0.2941994186781246, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.29824339694174146, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.2952104132440288, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.266902565398711, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 508.0'),
#  Text(0.3053203589030709, 0.725, 'B/B Score.4 <= 131.5\nsquared_error = 2.347\nsamples = 11\nvalue = 519.95'),
#  Text(0.29925439150764566, 0.675, 'Days Before Exam.2 <= 9.5\nsquared_error = 1.025\nsamples = 9\nvalue = 519.556'),
#  Text(0.2931884241122204, 0.625, 'P/S Score.3 <= 128.0\nsquared_error = 1.551\nsamples = 3\nvalue = 518.857'),
#  Text(0.291166434980412, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.2952104132440288, 0.575, 'B/B Score.3 <= 130.0\nsquared_error = 0.24\nsamples = 2\nvalue = 519.6'),
#  Text(0.2931884241122204, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.29723240237583726, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.3053203589030709, 0.625, 'B/B Score.4 <= 130.5\nsquared_error = 0.182\nsamples = 6\nvalue = 520.0'),
#  Text(0.30329836977126245, 0.575, 'P/S Score.4 <= 126.5\nsquared_error = 0.09\nsamples = 5\nvalue = 519.9'),
#  Text(0.30127638063945406, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.3053203589030709, 0.525, 'squared_error = 0.0\nsamples = 4\nvalue = 520.0'),
#  Text(0.3073423480348793, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.31138632629849616, 0.675, 'Days Before Exam.4 <= 10.5\nsquared_error = 0.25\nsamples = 2\nvalue = 523.5'),
#  Text(0.3093643371666877, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.31340831543030456, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.39062697459876156, 0.825, 'C/P Score.2 <= 128.5\nsquared_error = 11.634\nsamples = 99\nvalue = 517.867'),
#  Text(0.34967774548211805, 0.775, 'B/B Score.4 <= 127.5\nsquared_error = 11.394\nsamples = 42\nvalue = 516.077'),
#  Text(0.32680399342853533, 0.725, 'C/P Score.1 <= 125.5\nsquared_error = 9.978\nsamples = 24\nvalue = 514.459'),
#  Text(0.3194742828257298, 0.675, 'C/P Score.4 <= 125.5\nsquared_error = 0.222\nsamples = 2\nvalue = 509.333'),
#  Text(0.3174522936939214, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 509.0'),
#  Text(0.3214962719575382, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.33413370403134085, 0.675, 'P/S Score.3 <= 128.5\nsquared_error = 8.316\nsamples = 22\nvalue = 514.912'),
#  Text(0.32554025022115507, 0.625, 'CARS Score.2 <= 128.5\nsquared_error = 7.043\nsamples = 15\nvalue = 513.955'),
#  Text(0.320485277391634, 0.575, 'B/B Score.3 <= 126.5\nsquared_error = 2.988\nsamples = 5\nvalue = 512.111'),
#  Text(0.3184632882598256, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.3225072665234424, 0.525, 'P/S Score.1 <= 128.5\nsquared_error = 0.24\nsamples = 3\nvalue = 510.6'),
#  Text(0.320485277391634, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.32452925565525087, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 511.0'),
#  Text(0.3305952230506761, 0.575, 'B/B Score.3 <= 126.0\nsquared_error = 5.87\nsamples = 10\nvalue = 515.231'),
#  Text(0.32857323391886767, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.3326172121824845, 0.525, 'C/P Score.1 <= 126.5\nsquared_error = 3.889\nsamples = 9\nvalue = 515.667'),
#  Text(0.32857323391886767, 0.475, 'Days Before Exam.1 <= 4.5\nsquared_error = 0.222\nsamples = 2\nvalue = 513.333'),
#  Text(0.32655124478705927, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.3305952230506761, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.3366611904461014, 0.475, 'B/B Score.1 <= 129.5\nsquared_error = 2.691\nsamples = 7\nvalue = 516.444'),
#  Text(0.3346392013142929, 0.425, 'Days Before Exam.1 <= 4.5\nsquared_error = 1.25\nsamples = 6\nvalue = 516.0'),
#  Text(0.3305952230506761, 0.375, 'Days Before Exam.3 <= 16.0\nsquared_error = 0.64\nsamples = 3\nvalue = 515.4'),
#  Text(0.32857323391886767, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.3326172121824845, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.3386831795779098, 0.375, 'Days Before Exam.3 <= 24.5\nsquared_error = 0.667\nsamples = 3\nvalue = 517.0'),
#  Text(0.3366611904461014, 0.325, 'C/P Score.4 <= 127.5\nsquared_error = 0.25\nsamples = 2\nvalue = 517.5'),
#  Text(0.3346392013142929, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.3386831795779098, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.3407051687097182, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.3386831795779098, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.3427271578415266, 0.625, 'Days Before Exam.2 <= 13.0\nsquared_error = 5.889\nsamples = 7\nvalue = 516.667'),
#  Text(0.3386831795779098, 0.575, 'C/P Score.1 <= 128.5\nsquared_error = 0.222\nsamples = 3\nvalue = 514.333'),
#  Text(0.3366611904461014, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.3407051687097182, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.34677113610514343, 0.575, 'CARS Score.4 <= 128.5\nsquared_error = 0.667\nsamples = 4\nvalue = 519.0'),
#  Text(0.34474914697333503, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.34879312523695183, 0.525, 'B/B Score.1 <= 128.5\nsquared_error = 0.25\nsamples = 3\nvalue = 518.5'),
#  Text(0.34677113610514343, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.3508151143687603, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 519.0'),
#  Text(0.37255149753570077, 0.725, 'C/P Score.3 <= 127.5\nsquared_error = 5.24\nsamples = 18\nvalue = 518.214'),
#  Text(0.363958043725515, 0.675, 'CARS Score.2 <= 130.5\nsquared_error = 4.684\nsamples = 10\nvalue = 517.062'),
#  Text(0.35890307089599394, 0.625, 'Days Before Exam.4 <= 20.5\nsquared_error = 1.802\nsamples = 6\nvalue = 515.444'),
#  Text(0.3548590926323771, 0.575, 'Days Before Exam.4 <= 16.5\nsquared_error = 0.64\nsamples = 3\nvalue = 516.4'),
#  Text(0.3528371035005687, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 516.0'),
#  Text(0.35688108176418554, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.3629470491596108, 0.575, 'C/P Score.1 <= 128.0\nsquared_error = 0.688\nsamples = 3\nvalue = 514.25'),
#  Text(0.36092506002780234, 0.525, 'C/P Score.1 <= 126.5\nsquared_error = 0.25\nsamples = 2\nvalue = 513.5'),
#  Text(0.35890307089599394, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.3629470491596108, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.3649690382914192, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.36901301655503604, 0.625, 'Days Before Exam.2 <= 8.5\nsquared_error = 0.694\nsamples = 4\nvalue = 519.143'),
#  Text(0.3669910274232276, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.37103500568684444, 0.575, 'Days Before Exam.3 <= 30.0\nsquared_error = 0.139\nsamples = 3\nvalue = 518.833'),
#  Text(0.36901301655503604, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 519.0'),
#  Text(0.37305699481865284, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.3811449513458865, 0.675, 'C/P Score.3 <= 128.5\nsquared_error = 1.854\nsamples = 8\nvalue = 519.75'),
#  Text(0.3771009730822697, 0.625, 'Days Before Exam.1 <= 5.5\nsquared_error = 0.21\nsamples = 6\nvalue = 520.3'),
#  Text(0.37507898395046124, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.3791229622140781, 0.575, 'squared_error = 0.0\nsamples = 4\nvalue = 520.0'),
#  Text(0.38518892960950335, 0.625, 'Days Before Exam.1 <= 5.5\nsquared_error = 1.0\nsamples = 2\nvalue = 517.0'),
#  Text(0.38316694047769495, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.38721091874131175, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.431576203715405, 0.775, 'B/B Score.3 <= 129.5\nsquared_error = 7.997\nsamples = 57\nvalue = 519.118'),
#  Text(0.40908947301908255, 0.725, 'CARS Score.2 <= 128.5\nsquared_error = 8.07\nsamples = 40\nvalue = 518.22'),
#  Text(0.39732086440035386, 0.675, 'Days Before Exam.2 <= 11.0\nsquared_error = 5.481\nsamples = 12\nvalue = 516.136'),
#  Text(0.393276886136737, 0.625, 'Days Before Exam.3 <= 35.0\nsquared_error = 6.84\nsamples = 7\nvalue = 517.6'),
#  Text(0.3912548970049286, 0.575, 'CARS Score.3 <= 129.5\nsquared_error = 2.222\nsamples = 6\nvalue = 518.333'),
#  Text(0.3892329078731202, 0.525, 'B/B Score.4 <= 129.5\nsquared_error = 0.609\nsamples = 5\nvalue = 517.875'),
#  Text(0.38721091874131175, 0.475, 'C/P Score.4 <= 126.5\nsquared_error = 0.122\nsamples = 4\nvalue = 518.143'),
#  Text(0.38518892960950335, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.3892329078731202, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 518.0'),
#  Text(0.3912548970049286, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.393276886136737, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.39529887526854546, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.40136484266397066, 0.625, 'P/S Score.3 <= 130.5\nsquared_error = 1.076\nsamples = 5\nvalue = 514.917'),
#  Text(0.39934285353216226, 0.575, 'P/S Score.3 <= 128.5\nsquared_error = 0.25\nsamples = 4\nvalue = 514.5'),
#  Text(0.39732086440035386, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.40136484266397066, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.4033868317957791, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.4208580816378112, 0.675, 'C/P Score.4 <= 126.5\nsquared_error = 5.492\nsamples = 28\nvalue = 519.459'),
#  Text(0.41147478832301276, 0.625, 'P/S Score.1 <= 130.0\nsquared_error = 11.5\nsamples = 4\nvalue = 517.0'),
#  Text(0.4074308100593959, 0.575, 'P/S Score.4 <= 128.0\nsquared_error = 4.0\nsamples = 2\nvalue = 514.0'),
#  Text(0.4054088209275875, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.40945279919120436, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.4155187665866296, 0.575, 'Days Before Exam.1 <= 5.0\nsquared_error = 1.0\nsamples = 2\nvalue = 520.0'),
#  Text(0.41349677745482116, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.417540755718438, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.4302413749526096, 0.625, 'B/B Score.4 <= 126.5\nsquared_error = 3.941\nsamples = 24\nvalue = 519.758'),
#  Text(0.42360672311386327, 0.575, 'B/B Score.3 <= 128.5\nsquared_error = 3.188\nsamples = 3\nvalue = 517.75'),
#  Text(0.42158473398205487, 0.525, 'CARS Score.1 <= 129.5\nsquared_error = 0.25\nsamples = 2\nvalue = 519.5'),
#  Text(0.4195627448502464, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.42360672311386327, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.42562871224567167, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.436876026791356, 0.575, 'B/B Score.2 <= 131.5\nsquared_error = 3.413\nsamples = 21\nvalue = 520.034'),
#  Text(0.43485403765954755, 0.525, 'CARS Score.2 <= 131.5\nsquared_error = 2.932\nsamples = 20\nvalue = 520.179'),
#  Text(0.42765070137748007, 0.475, 'CARS Score.3 <= 130.5\nsquared_error = 2.692\nsamples = 18\nvalue = 520.0'),
#  Text(0.41930999620877035, 0.425, 'Days Before Exam.2 <= 12.5\nsquared_error = 1.84\nsamples = 13\nvalue = 520.4'),
#  Text(0.4137495260962972, 0.375, 'C/P Score.4 <= 127.5\nsquared_error = 0.139\nsamples = 4\nvalue = 521.833'),
#  Text(0.4117275369644888, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.4157715152281056, 0.325, 'squared_error = 0.0\nsamples = 3\nvalue = 522.0'),
#  Text(0.42487046632124353, 0.375, 'Days Before Exam.4 <= 34.5\nsquared_error = 1.311\nsamples = 9\nvalue = 519.786'),
#  Text(0.4198154934917225, 0.325, 'CARS Score.1 <= 129.5\nsquared_error = 0.222\nsamples = 3\nvalue = 518.667'),
#  Text(0.4177935043599141, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 519.0'),
#  Text(0.4218374826235309, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.4299254391507646, 0.325, 'CARS Score.4 <= 129.5\nsquared_error = 0.484\nsamples = 6\nvalue = 520.625'),
#  Text(0.42588146088714773, 0.275, 'P/S Score.2 <= 128.5\nsquared_error = 0.16\nsamples = 4\nvalue = 520.2'),
#  Text(0.42385947175533933, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.42790345001895613, 0.225, 'squared_error = 0.0\nsamples = 3\nvalue = 520.0'),
#  Text(0.4339694174143814, 0.275, 'P/S Score.1 <= 130.0\nsquared_error = 0.222\nsamples = 2\nvalue = 521.333'),
#  Text(0.431947428282573, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.43599140654618984, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.43599140654618984, 0.425, 'CARS Score.1 <= 129.5\nsquared_error = 3.222\nsamples = 5\nvalue = 518.667'),
#  Text(0.4339694174143814, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.43801339567799824, 0.375, 'C/P Score.2 <= 129.5\nsquared_error = 0.64\nsamples = 4\nvalue = 519.4'),
#  Text(0.43599140654618984, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 520.0'),
#  Text(0.44003538480980664, 0.325, 'B/B Score.1 <= 129.5\nsquared_error = 0.25\nsamples = 2\nvalue = 518.5'),
#  Text(0.43801339567799824, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.44205737394161504, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.44205737394161504, 0.475, 'C/P Score.3 <= 130.0\nsquared_error = 0.25\nsamples = 2\nvalue = 522.5'),
#  Text(0.44003538480980664, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.4440793630734235, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.4388980159231644, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.4540629344117275, 0.725, 'Days Before Exam.3 <= 13.5\nsquared_error = 4.042\nsamples = 17\nvalue = 520.676'),
#  Text(0.4490079615822065, 0.675, 'P/S Score.3 <= 129.5\nsquared_error = 2.828\nsamples = 7\nvalue = 522.308'),
#  Text(0.44698597245039806, 0.625, 'Days Before Exam.2 <= 15.0\nsquared_error = 0.85\nsamples = 5\nvalue = 521.5'),
#  Text(0.44496398331858966, 0.575, 'B/B Score.2 <= 128.5\nsquared_error = 0.173\nsamples = 4\nvalue = 521.778'),
#  Text(0.44294199418678126, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.44698597245039806, 0.525, 'squared_error = 0.0\nsamples = 3\nvalue = 522.0'),
#  Text(0.4490079615822065, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.4510299507140149, 0.625, 'squared_error = 0.0\nsamples = 2\nvalue = 525.0'),
#  Text(0.45911790724124857, 0.675, 'B/B Score.2 <= 130.5\nsquared_error = 2.127\nsamples = 10\nvalue = 519.667'),
#  Text(0.45507392897763177, 0.625, 'CARS Score.3 <= 131.0\nsquared_error = 0.875\nsamples = 8\nvalue = 519.0'),
#  Text(0.4530519398458233, 0.575, 'P/S Score.2 <= 129.5\nsquared_error = 0.293\nsamples = 7\nvalue = 519.2'),
#  Text(0.4510299507140149, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 520.0'),
#  Text(0.45507392897763177, 0.525, 'P/S Score.1 <= 129.0\nsquared_error = 0.167\nsamples = 5\nvalue = 519.0'),
#  Text(0.4530519398458233, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.45709591810944017, 0.475, 'C/P Score.1 <= 128.0\nsquared_error = 0.083\nsamples = 4\nvalue = 518.909'),
#  Text(0.45507392897763177, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.45911790724124857, 0.425, 'squared_error = 0.0\nsamples = 3\nvalue = 519.0'),
#  Text(0.45709591810944017, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.4631618855048654, 0.625, 'Days Before Exam.1 <= 5.5\nsquared_error = 0.16\nsamples = 2\nvalue = 521.8'),
#  Text(0.46113989637305697, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.4651838746366738, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.6646617907241249, 0.925, 'B/B Score.3 <= 129.5\nsquared_error = 14.241\nsamples = 348\nvalue = 520.548'),
#  Text(0.5550992038417794, 0.875, 'CARS Score.4 <= 127.5\nsquared_error = 11.329\nsamples = 119\nvalue = 517.884'),
#  Text(0.5076456464046506, 0.825, 'CARS Score.3 <= 126.5\nsquared_error = 9.162\nsamples = 43\nvalue = 515.733'),
#  Text(0.4942499684064198, 0.775, 'C/P Score.1 <= 130.5\nsquared_error = 7.303\nsamples = 22\nvalue = 514.29'),
#  Text(0.4848982686718059, 0.725, 'Days Before Exam.4 <= 43.5\nsquared_error = 3.773\nsamples = 13\nvalue = 513.19'),
#  Text(0.47832680399342853, 0.675, 'P/S Score.2 <= 126.5\nsquared_error = 2.284\nsamples = 11\nvalue = 512.778'),
#  Text(0.4712498420320991, 0.625, 'P/S Score.2 <= 125.5\nsquared_error = 0.531\nsamples = 3\nvalue = 514.429'),
#  Text(0.4692278529002907, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.4732718311639075, 0.575, 'Days Before Exam.1 <= 6.0\nsquared_error = 0.25\nsamples = 2\nvalue = 515.5'),
#  Text(0.4712498420320991, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.47529382029571593, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.485403765954758, 0.625, 'B/B Score.1 <= 129.5\nsquared_error = 0.562\nsamples = 8\nvalue = 511.727'),
#  Text(0.4813597876911412, 0.575, 'B/B Score.4 <= 130.5\nsquared_error = 0.222\nsamples = 6\nvalue = 512.0'),
#  Text(0.47933779855933273, 0.525, 'CARS Score.2 <= 124.0\nsquared_error = 0.109\nsamples = 5\nvalue = 512.125'),
#  Text(0.47731580942752433, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 513.0'),
#  Text(0.4813597876911412, 0.475, 'squared_error = 0.0\nsamples = 4\nvalue = 512.0'),
#  Text(0.4833817768229496, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.48944774421837484, 0.575, 'Days Before Exam.2 <= 7.5\nsquared_error = 0.25\nsamples = 2\nvalue = 510.5'),
#  Text(0.48742575508656644, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 510.0'),
#  Text(0.49146973335018324, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.49146973335018324, 0.675, 'P/S Score.1 <= 130.0\nsquared_error = 5.556\nsamples = 2\nvalue = 515.667'),
#  Text(0.48944774421837484, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.49349172248199163, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5036016681410337, 0.725, 'Days Before Exam.1 <= 5.0\nsquared_error = 6.84\nsamples = 9\nvalue = 516.6'),
#  Text(0.4995576898774169, 0.675, 'Days Before Exam.3 <= 15.5\nsquared_error = 1.688\nsamples = 4\nvalue = 518.75'),
#  Text(0.4975357007456085, 0.625, 'Days Before Exam.1 <= 2.5\nsquared_error = 0.25\nsamples = 2\nvalue = 517.5'),
#  Text(0.4955137116138001, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.4995576898774169, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5015796790092253, 0.625, 'squared_error = 0.0\nsamples = 2\nvalue = 520.0'),
#  Text(0.5076456464046506, 0.675, 'B/B Score.2 <= 129.5\nsquared_error = 5.139\nsamples = 5\nvalue = 515.167'),
#  Text(0.5056236572728422, 0.625, 'squared_error = 0.0\nsamples = 2\nvalue = 512.0'),
#  Text(0.509667635536459, 0.625, 'P/S Score.4 <= 128.0\nsquared_error = 0.188\nsamples = 3\nvalue = 516.75'),
#  Text(0.5076456464046506, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 517.0'),
#  Text(0.5116896246682674, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5210413244028813, 0.775, 'P/S Score.1 <= 128.5\nsquared_error = 6.545\nsamples = 21\nvalue = 517.276'),
#  Text(0.5137116138000758, 0.725, 'B/B Score.4 <= 129.0\nsquared_error = 0.96\nsamples = 4\nvalue = 514.2'),
#  Text(0.5116896246682674, 0.675, 'squared_error = 0.0\nsamples = 2\nvalue = 515.0'),
#  Text(0.5157336029318842, 0.675, 'squared_error = 0.0\nsamples = 2\nvalue = 513.0'),
#  Text(0.5283710350056868, 0.725, 'C/P Score.3 <= 128.5\nsquared_error = 5.326\nsamples = 17\nvalue = 517.917'),
#  Text(0.5197775811955011, 0.675, 'P/S Score.1 <= 129.5\nsquared_error = 1.688\nsamples = 3\nvalue = 515.25'),
#  Text(0.5177555920636927, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5217995703273095, 0.625, 'P/S Score.4 <= 128.0\nsquared_error = 0.25\nsamples = 2\nvalue = 516.5'),
#  Text(0.5197775811955011, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.5238215594591179, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5369644888158727, 0.675, 'Days Before Exam.4 <= 50.0\nsquared_error = 4.347\nsamples = 14\nvalue = 518.45'),
#  Text(0.5319095159863516, 0.625, 'CARS Score.2 <= 127.5\nsquared_error = 2.902\nsamples = 11\nvalue = 517.812'),
#  Text(0.5278655377227347, 0.575, 'P/S Score.4 <= 129.5\nsquared_error = 0.49\nsamples = 6\nvalue = 516.9'),
#  Text(0.5258435485909263, 0.525, 'Days Before Exam.2 <= 17.0\nsquared_error = 0.099\nsamples = 5\nvalue = 517.111'),
#  Text(0.5238215594591179, 0.475, 'squared_error = 0.0\nsamples = 4\nvalue = 517.0'),
#  Text(0.5278655377227347, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.5298875268545432, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.5359534942499684, 0.575, 'B/B Score.3 <= 128.0\nsquared_error = 3.222\nsamples = 5\nvalue = 519.333'),
#  Text(0.53393150511816, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.5379754833817768, 0.525, 'C/P Score.3 <= 129.5\nsquared_error = 0.64\nsamples = 4\nvalue = 518.6'),
#  Text(0.5359534942499684, 0.475, 'P/S Score.1 <= 129.5\nsquared_error = 0.25\nsamples = 2\nvalue = 519.5'),
#  Text(0.53393150511816, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5379754833817768, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5399974725135852, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 518.0'),
#  Text(0.5420194616453936, 0.625, 'P/S Score.2 <= 130.5\nsquared_error = 2.0\nsamples = 3\nvalue = 521.0'),
#  Text(0.5399974725135852, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5440414507772021, 0.575, 'C/P Score.2 <= 131.5\nsquared_error = 0.889\nsamples = 2\nvalue = 521.667'),
#  Text(0.5420194616453936, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.5460634399090105, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.6025527612789081, 0.825, 'C/P Score.3 <= 129.5\nsquared_error = 8.973\nsamples = 76\nvalue = 518.95'),
#  Text(0.5756350309617085, 0.775, 'B/B Score.3 <= 127.5\nsquared_error = 6.596\nsamples = 47\nvalue = 517.667'),
#  Text(0.5652723366611905, 0.725, 'B/B Score.1 <= 128.5\nsquared_error = 6.84\nsamples = 13\nvalue = 515.6'),
#  Text(0.558195374699861, 0.675, 'Days Before Exam.3 <= 106.0\nsquared_error = 4.017\nsamples = 7\nvalue = 513.727'),
#  Text(0.5541513964362441, 0.625, 'B/B Score.1 <= 127.5\nsquared_error = 0.543\nsamples = 5\nvalue = 512.889'),
#  Text(0.5521294073044357, 0.575, 'CARS Score.4 <= 130.5\nsquared_error = 0.222\nsamples = 4\nvalue = 513.333'),
#  Text(0.5501074181726273, 0.525, 'squared_error = 0.0\nsamples = 3\nvalue = 513.0'),
#  Text(0.5541513964362441, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.5561733855680526, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 512.0'),
#  Text(0.5622393529634778, 0.625, 'B/B Score.1 <= 126.5\nsquared_error = 2.25\nsamples = 2\nvalue = 517.5'),
#  Text(0.5602173638316694, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.5642613420952862, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.5723492986225199, 0.675, 'C/P Score.4 <= 128.5\nsquared_error = 0.765\nsamples = 6\nvalue = 517.889'),
#  Text(0.5703273094907115, 0.625, 'P/S Score.3 <= 128.0\nsquared_error = 0.234\nsamples = 5\nvalue = 517.625'),
#  Text(0.568305320358903, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 517.0'),
#  Text(0.5723492986225199, 0.575, 'squared_error = 0.0\nsamples = 3\nvalue = 518.0'),
#  Text(0.5743712877543283, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5859977252622267, 0.725, 'CARS Score.3 <= 124.5\nsquared_error = 4.389\nsamples = 34\nvalue = 518.418'),
#  Text(0.5839757361304183, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 511.0'),
#  Text(0.5880197143940351, 0.675, 'Days Before Exam.2 <= 57.0\nsquared_error = 3.432\nsamples = 33\nvalue = 518.556'),
#  Text(0.5859977252622267, 0.625, 'P/S Score.4 <= 128.5\nsquared_error = 2.735\nsamples = 32\nvalue = 518.731'),
#  Text(0.5763932768861367, 0.575, 'B/B Score.4 <= 125.5\nsquared_error = 1.819\nsamples = 18\nvalue = 518.156'),
#  Text(0.5743712877543283, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.5784152660179451, 0.525, 'C/P Score.3 <= 126.5\nsquared_error = 1.366\nsamples = 17\nvalue = 517.967'),
#  Text(0.5763932768861367, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.5804372551497535, 0.475, 'P/S Score.1 <= 131.5\nsquared_error = 1.147\nsamples = 16\nvalue = 517.821'),
#  Text(0.5763932768861367, 0.425, 'Days Before Exam.3 <= 9.5\nsquared_error = 0.85\nsamples = 12\nvalue = 517.5'),
# ...
#  Text(0.8177682294957664, 0.725, 'CARS Score.3 <= 129.5\nsquared_error = 3.492\nsamples = 23\nvalue = 521.088'),
#  Text(0.8114495134588652, 0.675, 'CARS Score.1 <= 128.5\nsquared_error = 2.665\nsamples = 16\nvalue = 520.458'),
#  Text(0.8048780487804879, 0.625, 'Days Before Exam.2 <= 12.5\nsquared_error = 1.629\nsamples = 12\nvalue = 519.947'),
#  Text(0.7998230759509668, 0.575, 'P/S Score.1 <= 130.5\nsquared_error = 1.139\nsamples = 5\nvalue = 518.833'),
#  Text(0.7978010868191584, 0.525, 'Days Before Exam.3 <= 13.0\nsquared_error = 0.24\nsamples = 4\nvalue = 518.4'),
#  Text(0.7957790976873499, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 519.0'),
#  Text(0.7998230759509668, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 518.0'),
#  Text(0.8018450650827752, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8099330216100088, 0.575, 'Days Before Exam.1 <= 5.5\nsquared_error = 1.018\nsamples = 7\nvalue = 520.462'),
#  Text(0.805889043346392, 0.525, 'B/B Score.1 <= 131.0\nsquared_error = 0.24\nsamples = 3\nvalue = 521.4'),
#  Text(0.8038670542145836, 0.475, 'squared_error = 0.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.8079110324782004, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.8139769998736257, 0.525, 'CARS Score.3 <= 128.0\nsquared_error = 0.609\nsamples = 4\nvalue = 519.875'),
#  Text(0.8119550107418173, 0.475, 'CARS Score.2 <= 127.5\nsquared_error = 0.122\nsamples = 3\nvalue = 520.143'),
#  Text(0.8099330216100088, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 520.0'),
#  Text(0.8139769998736257, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8159989890054341, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 518.0'),
#  Text(0.8180209781372425, 0.625, 'C/P Score.4 <= 129.5\nsquared_error = 1.84\nsamples = 4\nvalue = 522.4'),
#  Text(0.8159989890054341, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 525.0'),
#  Text(0.8200429672690509, 0.575, 'Days Before Exam.1 <= 5.5\nsquared_error = 0.188\nsamples = 3\nvalue = 521.75'),
#  Text(0.8180209781372425, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8220649564008593, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 522.0'),
#  Text(0.8240869455326678, 0.675, 'CARS Score.4 <= 125.5\nsquared_error = 2.24\nsamples = 7\nvalue = 522.6'),
#  Text(0.8220649564008593, 0.625, 'squared_error = 0.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.8261089346644762, 0.625, 'C/P Score.4 <= 131.0\nsquared_error = 0.889\nsamples = 5\nvalue = 523.667'),
#  Text(0.8240869455326678, 0.575, 'squared_error = 0.0\nsamples = 3\nvalue = 523.0'),
#  Text(0.8281309237962846, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 525.0'),
#  Text(0.8803946038165045, 0.775, 'P/S Score.3 <= 128.5\nsquared_error = 7.552\nsamples = 103\nvalue = 523.665'),
#  Text(0.8577025148489826, 0.725, 'C/P Score.1 <= 131.5\nsquared_error = 10.447\nsamples = 27\nvalue = 522.071'),
#  Text(0.844812334133704, 0.675, 'CARS Score.3 <= 129.5\nsquared_error = 13.087\nsamples = 11\nvalue = 519.824'),
#  Text(0.8362188803235182, 0.625, 'C/P Score.3 <= 130.5\nsquared_error = 1.359\nsamples = 5\nvalue = 522.875'),
#  Text(0.8321749020599014, 0.575, 'CARS Score.4 <= 128.5\nsquared_error = 0.64\nsamples = 3\nvalue = 523.6'),
#  Text(0.830152912928093, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 524.0'),
#  Text(0.8341968911917098, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.8402628585871351, 0.575, 'CARS Score.3 <= 127.5\nsquared_error = 0.222\nsamples = 2\nvalue = 521.667'),
#  Text(0.8382408694553267, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.8422848477189435, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8534057879438898, 0.625, 'Days Before Exam.1 <= 6.5\nsquared_error = 7.877\nsamples = 6\nvalue = 517.111'),
#  Text(0.8483508151143687, 0.575, 'B/B Score.3 <= 131.5\nsquared_error = 0.25\nsamples = 2\nvalue = 514.5'),
#  Text(0.8463288259825603, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 515.0'),
#  Text(0.8503728042461772, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.8584607607734108, 0.575, 'Days Before Exam.4 <= 32.5\nsquared_error = 4.16\nsamples = 4\nvalue = 519.2'),
#  Text(0.854416782509794, 0.525, 'Days Before Exam.2 <= 9.5\nsquared_error = 0.25\nsamples = 2\nvalue = 521.5'),
#  Text(0.8523947933779856, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8564387716416024, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.8625047390370276, 0.525, 'Days Before Exam.1 <= 14.0\nsquared_error = 0.889\nsamples = 2\nvalue = 517.667'),
#  Text(0.8604827499052192, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 519.0'),
#  Text(0.8645267281688361, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0'),
#  Text(0.8705926955642613, 0.675, 'CARS Score.2 <= 127.0\nsquared_error = 2.88\nsamples = 16\nvalue = 523.6'),
#  Text(0.8685707064324529, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.8726146846960697, 0.625, 'Days Before Exam.4 <= 60.5\nsquared_error = 1.905\nsamples = 15\nvalue = 523.913'),
#  Text(0.8705926955642613, 0.575, 'P/S Score.4 <= 127.5\nsquared_error = 1.198\nsamples = 14\nvalue = 523.727'),
#  Text(0.8685707064324529, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 522.0'),
#  Text(0.8726146846960697, 0.525, 'CARS Score.4 <= 129.5\nsquared_error = 0.99\nsamples = 12\nvalue = 523.9'),
#  Text(0.8685707064324529, 0.475, 'Days Before Exam.1 <= 7.5\nsquared_error = 0.667\nsamples = 6\nvalue = 523.333'),
#  Text(0.8665487173006445, 0.425, 'Days Before Exam.3 <= 22.0\nsquared_error = 0.204\nsamples = 5\nvalue = 523.714'),
#  Text(0.8645267281688361, 0.375, 'squared_error = 0.0\nsamples = 3\nvalue = 524.0'),
#  Text(0.8685707064324529, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 523.0'),
#  Text(0.8705926955642613, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.8766586629596866, 0.475, 'B/B Score.3 <= 130.5\nsquared_error = 0.777\nsamples = 6\nvalue = 524.364'),
#  Text(0.8746366738278781, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.878680652091495, 0.425, 'P/S Score.1 <= 129.5\nsquared_error = 0.444\nsamples = 5\nvalue = 524.667'),
#  Text(0.8766586629596866, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 524.0'),
#  Text(0.8807026412233034, 0.375, 'P/S Score.2 <= 129.5\nsquared_error = 0.16\nsamples = 3\nvalue = 525.2'),
#  Text(0.878680652091495, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 526.0'),
#  Text(0.8827246303551118, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 525.0'),
#  Text(0.8746366738278781, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 528.0'),
#  Text(0.9030866927840263, 0.725, 'C/P Score.3 <= 129.5\nsquared_error = 5.44\nsamples = 76\nvalue = 524.2'),
#  Text(0.878680652091495, 0.675, 'B/B Score.3 <= 130.5\nsquared_error = 10.25\nsamples = 3\nvalue = 519.5'),
#  Text(0.8766586629596866, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 514.0'),
#  Text(0.8807026412233034, 0.625, 'B/B Score.2 <= 131.0\nsquared_error = 0.222\nsamples = 2\nvalue = 521.333'),
#  Text(0.878680652091495, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8827246303551118, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.9274927334765576, 0.675, 'P/S Score.2 <= 130.5\nsquared_error = 4.527\nsamples = 73\nvalue = 524.355'),
#  Text(0.8946038165044863, 0.625, 'B/B Score.4 <= 129.5\nsquared_error = 5.591\nsamples = 16\nvalue = 522.963'),
#  Text(0.8867686086187286, 0.575, 'P/S Score.1 <= 130.0\nsquared_error = 3.556\nsamples = 2\nvalue = 518.667'),
#  Text(0.8847466194869202, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.888790597750537, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 516.0'),
#  Text(0.9024390243902439, 0.575, 'CARS Score.3 <= 131.5\nsquared_error = 3.25\nsamples = 14\nvalue = 523.5'),
#  Text(0.892834576014154, 0.525, 'Days Before Exam.4 <= 23.0\nsquared_error = 1.619\nsamples = 9\nvalue = 522.706'),
#  Text(0.8877796031846329, 0.475, 'Days Before Exam.4 <= 16.5\nsquared_error = 0.234\nsamples = 4\nvalue = 523.625'),
#  Text(0.8857576140528245, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 524.0'),
#  Text(0.8898015923164413, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 523.0'),
#  Text(0.897889548843675, 0.475, 'Days Before Exam.2 <= 14.5\nsquared_error = 1.432\nsamples = 5\nvalue = 521.889'),
#  Text(0.8938455705800581, 0.425, 'CARS Score.2 <= 129.5\nsquared_error = 0.472\nsamples = 3\nvalue = 521.167'),
#  Text(0.8918235814482497, 0.375, 'C/P Score.1 <= 131.0\nsquared_error = 0.188\nsamples = 2\nvalue = 520.75'),
#  Text(0.8898015923164413, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.8938455705800581, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 521.0'),
#  Text(0.8958675597118666, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.9019335271072918, 0.425, 'C/P Score.2 <= 131.5\nsquared_error = 0.222\nsamples = 2\nvalue = 523.333'),
#  Text(0.8999115379754834, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.9039555162391002, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9120434727663339, 0.525, 'CARS Score.1 <= 130.5\nsquared_error = 1.959\nsamples = 5\nvalue = 525.429'),
#  Text(0.907999494502717, 0.475, 'Days Before Exam.1 <= 6.0\nsquared_error = 0.24\nsamples = 3\nvalue = 524.6'),
#  Text(0.9059775053709086, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.9100214836345255, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 525.0'),
#  Text(0.9160874510299507, 0.475, 'B/B Score.4 <= 130.5\nsquared_error = 0.25\nsamples = 2\nvalue = 527.5'),
#  Text(0.9140654618981423, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 527.0'),
#  Text(0.9181094401617591, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 528.0'),
#  Text(0.9603816504486289, 0.625, 'P/S Score.4 <= 129.5\nsquared_error = 3.504\nsamples = 57\nvalue = 524.755'),
#  Text(0.941867812460508, 0.575, 'Days Before Exam.4 <= 31.0\nsquared_error = 2.151\nsamples = 25\nvalue = 525.4'),
#  Text(0.9332743586503223, 0.525, 'Days Before Exam.1 <= 6.5\nsquared_error = 2.337\nsamples = 15\nvalue = 524.857'),
#  Text(0.9261973966889928, 0.475, 'Days Before Exam.4 <= 20.5\nsquared_error = 1.938\nsamples = 9\nvalue = 525.75'),
#  Text(0.922153418425376, 0.425, 'B/B Score.4 <= 129.5\nsquared_error = 0.188\nsamples = 2\nvalue = 527.25'),
#  Text(0.9201314292935675, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 527.0'),
#  Text(0.9241754075571844, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 528.0'),
#  Text(0.9302413749526096, 0.425, 'Days Before Exam.3 <= 8.5\nsquared_error = 1.521\nsamples = 7\nvalue = 525.25'),
#  Text(0.9282193858208012, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 528.0'),
#  Text(0.932263364084418, 0.375, 'CARS Score.3 <= 129.5\nsquared_error = 0.909\nsamples = 6\nvalue = 525.0'),
#  Text(0.9282193858208012, 0.325, 'Days Before Exam.4 <= 25.5\nsquared_error = 0.25\nsamples = 2\nvalue = 523.5'),
#  Text(0.9261973966889928, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9302413749526096, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.9363073423480349, 0.325, 'Days Before Exam.2 <= 8.5\nsquared_error = 0.444\nsamples = 4\nvalue = 525.333'),
#  Text(0.9342853532162264, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 525.0'),
#  Text(0.9383293314798433, 0.275, 'CARS Score.3 <= 130.5\nsquared_error = 0.25\nsamples = 2\nvalue = 526.5'),
#  Text(0.9363073423480349, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 526.0'),
#  Text(0.9403513206116517, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 527.0'),
#  Text(0.9403513206116517, 0.475, 'P/S Score.1 <= 131.0\nsquared_error = 0.389\nsamples = 6\nvalue = 523.667'),
#  Text(0.9383293314798433, 0.425, 'Days Before Exam.3 <= 20.0\nsquared_error = 0.222\nsamples = 2\nvalue = 522.667'),
#  Text(0.9363073423480349, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.9403513206116517, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9423733097434601, 0.425, 'squared_error = 0.0\nsamples = 4\nvalue = 524.0'),
#  Text(0.9504612662706938, 0.525, 'CARS Score.1 <= 130.5\nsquared_error = 0.561\nsamples = 10\nvalue = 526.294'),
#  Text(0.9484392771388854, 0.475, 'C/P Score.1 <= 130.5\nsquared_error = 0.36\nsamples = 7\nvalue = 525.8'),
#  Text(0.9464172880070769, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.9504612662706938, 0.425, 'squared_error = 0.0\nsamples = 6\nvalue = 526.0'),
#  Text(0.9524832554025022, 0.475, 'squared_error = 0.0\nsamples = 3\nvalue = 527.0'),
#  Text(0.9788954884367497, 0.575, 'CARS Score.2 <= 131.5\nsquared_error = 4.014\nsamples = 32\nvalue = 524.163'),
#  Text(0.9638569442689245, 0.525, 'B/B Score.2 <= 129.5\nsquared_error = 2.006\nsamples = 26\nvalue = 524.488'),
#  Text(0.956527233666119, 0.475, 'CARS Score.1 <= 130.0\nsquared_error = 1.0\nsamples = 2\nvalue = 521.0'),
#  Text(0.9545052445343106, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 522.0'),
#  Text(0.9585492227979274, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 520.0'),
#  Text(0.9711866548717301, 0.475, 'B/B Score.1 <= 131.5\nsquared_error = 1.402\nsamples = 24\nvalue = 524.667'),
#  Text(0.9625932010615443, 0.425, 'C/P Score.1 <= 131.5\nsquared_error = 1.575\nsamples = 15\nvalue = 525.038'),
#  Text(0.9575382282320233, 0.375, 'Days Before Exam.2 <= 12.0\nsquared_error = 0.41\nsamples = 6\nvalue = 524.083'),
#  Text(0.9555162391002149, 0.325, 'Days Before Exam.3 <= 55.5\nsquared_error = 0.083\nsamples = 5\nvalue = 523.909'),
#  Text(0.9534942499684064, 0.275, 'squared_error = 0.0\nsamples = 4\nvalue = 524.0'),
#  Text(0.9575382282320233, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9595602173638317, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 526.0'),
#  Text(0.9676481738910654, 0.375, 'CARS Score.4 <= 129.0\nsquared_error = 1.122\nsamples = 9\nvalue = 525.857'),
#  Text(0.9636041956274485, 0.325, 'Days Before Exam.1 <= 9.0\nsquared_error = 0.25\nsamples = 2\nvalue = 523.5'),
#  Text(0.9615822064956401, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.9656261847592569, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9716921521546822, 0.325, 'P/S Score.1 <= 130.0\nsquared_error = 0.188\nsamples = 7\nvalue = 526.25'),
#  Text(0.9696701630228738, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 527.0'),
#  Text(0.9737141412864906, 0.275, 'B/B Score.2 <= 130.5\nsquared_error = 0.09\nsamples = 6\nvalue = 526.1'),
#  Text(0.9716921521546822, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 527.0'),
#  Text(0.975736130418299, 0.225, 'squared_error = 0.0\nsamples = 5\nvalue = 526.0'),
#  Text(0.9797801086819158, 0.425, 'CARS Score.1 <= 131.5\nsquared_error = 0.225\nsamples = 9\nvalue = 523.923'),
#  Text(0.9777581195501074, 0.375, 'CARS Score.1 <= 128.5\nsquared_error = 0.083\nsamples = 8\nvalue = 524.091'),
#  Text(0.975736130418299, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 525.0'),
#  Text(0.9797801086819158, 0.325, 'squared_error = 0.0\nsamples = 7\nvalue = 524.0'),
#  Text(0.9818020978137243, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9939340326045748, 0.525, 'C/P Score.3 <= 131.5\nsquared_error = 11.0\nsamples = 6\nvalue = 522.5'),
#  Text(0.9919120434727663, 0.475, 'CARS Score.1 <= 130.5\nsquared_error = 1.222\nsamples = 5\nvalue = 524.333'),
#  Text(0.9878680652091495, 0.425, 'Days Before Exam.2 <= 17.5\nsquared_error = 0.222\nsamples = 2\nvalue = 523.333'),
#  Text(0.9858460760773411, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 523.0'),
#  Text(0.9898900543409579, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 524.0'),
#  Text(0.9959560217363832, 0.425, 'CARS Score.4 <= 131.0\nsquared_error = 0.222\nsamples = 3\nvalue = 525.333'),
#  Text(0.9939340326045748, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 525.0'),
#  Text(0.9979780108681916, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 526.0'),
#  Text(0.9959560217363832, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 517.0')]

# %%
#conda uninstall python-graphviz
#conda uninstall graphviz
#pip install dtreeviz             # install dtreeviz for sklearn
#pip install dtreeviz[xgboost]    # install XGBoost related dependency
#pip install dtreeviz[pyspark]    # install pyspark related dependency
#pip install dtreeviz[lightgbm]   # install LightGBM related dependency
#pip install graphviz

# %%
from dtreeviz.trees import dtreeviz

viz = dtreeviz(rf.estimators_[0], X_train, y_train,
               target_name = "Real MCAT Score",
               feature_names = features,
               title = "Decision Tree for MCAT Scores")

viz.save("MCAT_decision_tree.svg")
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
